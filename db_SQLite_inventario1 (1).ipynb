# %% [markdown]
# # Gestión Básica de Inventario con SQLite3
#
# **Autor: Elias Buitrago B.**\
# Bogotá, Colombia \
# Actualizado: 22 abril 202a \
# _Nota: Código ajustado para su ejecución en Google Colaboratory_\

# %% [markdown]
# ## Instalar librerías SQLite3

# %%
# %%shell
# sudo apt-get install sqlite3
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# sqlite3 is already the newest version (3.37.2-2ubuntu0.5).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %% [markdown]
# ## Crear la base de datos y una tabla de inventario

# %%
import sqlite3
import random

# Crear la base de datos con SQlite
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# %%
# Crear una tabla llamada 'inventario'
c.execute('''
CREATE TABLE inventario (
    id INTEGER PRIMARY KEY,
    nombre TEXT,
    categoria TEXT,
    precio DECIMAL(10, 2),
    cantidad INTEGER,
    proveedor TEXT,
    fecha_ingreso DATE,
    ubicacion TEXT
)
''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipython-input-1957681289.py in <cell line: 0>()
#       1 # Crear una tabla llamada 'inventario'
# ----> 2 c.execute('''
#       3 CREATE TABLE inventario (
#       4     id INTEGER PRIMARY KEY,
#       5     nombre TEXT,
#
# OperationalError: table inventario already exists

# %%
# Generar datos de ejemplo para la tabla
def generar_producto(id):
    nombres = ["Producto", "Artículo", "Objeto"]
    categorias = ["Electrónica", "Hogar", "Jardín", "Moda", "Deportes"]
    proveedores = ["Proveedor1", "Proveedor2", "Proveedor3"]
    ubicaciones = ["Almacén A", "Almacén B", "Almacén C"]

    nombre = random.choice(nombres) + str(id)
    categoria = random.choice(categorias)
    precio = round(random.uniform(10.0, 500.0), 2)
    cantidad = random.randint(1, 100)
    proveedor = random.choice(proveedores)
    fecha_ingreso = f"2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}"
    ubicacion = random.choice(ubicaciones)

    return (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)

# Insertar 1000 productos en la tabla
productos = [generar_producto(i + 1) for i in range(10000)]
c.executemany('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', productos)

# Guardar cambios y cerrar la conexión
conn.commit()
conn.close()

# %%
print("Base de datos creada y poblada con éxito.")
# Out:
# Base de datos creada y poblada con éxito.

# %% [markdown]
# ## Consulta para mostrar todos los productos creados

# %%
import sqlite3

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Consultar todos los productos
c.execute('SELECT * FROM inventario')
productos = c.fetchall()

# Imprimir los productos
for producto in productos:
    print(producto)

# Cerrar la conexión
conn.close()
# Out:
# (1, 'Producto1', 'Jardín', 279.38, 56, 'Proveedor2', '2023-10-13', 'Almacén A')
# (2, 'Artículo2', 'Deportes', 13.34, 58, 'Proveedor2', '2023-02-21', 'Almacén C')
# (3, 'Producto3', 'Jardín', 269.48, 15, 'Proveedor3', '2023-08-10', 'Almacén B')
# (4, 'Artículo4', 'Deportes', 194.91, 10, 'Proveedor2', '2023-09-09', 'Almacén A')
# (5, 'Artículo5', 'Jardín', 77.88, 4, 'Proveedor3', '2023-12-20', 'Almacén A')
# (6, 'Producto6', 'Moda', 173.79, 82, 'Proveedor1', '2023-03-17', 'Almacén A')
# (7, 'Artículo7', 'Moda', 69.94, 90, 'Proveedor3', '2023-03-05', 'Almacén B')
# (8, 'Producto8', 'Hogar', 282.7, 60, 'Proveedor1', '2023-04-01', 'Almacén B')
# (9, 'Producto9', 'Hogar', 132.49, 3, 'Proveedor1', '2023-08-19', 'Almacén A')
# (10, 'Producto10', 'Deportes', 460.67, 81, 'Proveedor2', '2023-08-28', 'Almacén B')
# (11, 'Objeto11', 'Electrónica', 242.65, 79, 'Proveedor1', '2023-10-06', 'Almacén A')
# (12, 'Artículo12', 'Electrónica', 283.81, 71, 'Proveedor2', '2023-07-10', 'Almacén C')
# (13, 'Artículo13', 'Moda', 322.83, 11, 'Proveedor3', '2023-11-17', 'Almacén B')
# (14, 'Artículo14', 'Deportes', 344.16, 21, 'Proveedor1', '2023-06-08', 'Almacén C')
# (15, 'Objeto15', 'Jardín', 420.81, 86, 'Proveedor2', '2023-11-06', 'Almacén A')
# (16, 'Producto16', 'Hogar', 379.6, 8, 'Proveedor2', '2023-02-20', 'Almacén A')
# (17, 'Artículo17', 'Deportes', 47.38, 66, 'Proveedor2', '2023-02-18', 'Almacén B')
# (18, 'Artículo18', 'Hogar', 481.32, 15, 'Proveedor1', '2023-03-22', 'Almacén A')
# (19, 'Producto19', 'Hogar', 293.54, 28, 'Proveedor3', '2023-09-19', 'Almacén C')
# (20, 'Artículo20', 'Jardín', 342.92, 6, 'Proveedor2', '2023-06-22', 'Almacén A')
# (21, 'Producto21', 'Electrónica', 254.12, 62, 'Proveedor1', '2023-05-15', 'Almacén C')
# (22, 'Objeto22', 'Electrónica', 432.42, 47, 'Proveedor2', '2023-10-24', 'Almacén A')
# (23, 'Producto23', 'Moda', 223.87, 58, 'Proveedor1', '2023-04-23', 'Almacén A')
# (24, 'Objeto24', 'Moda', 289.7, 10, 'Proveedor2', '2023-03-10', 'Almacén C')
# (25, 'Objeto25', 'Electrónica', 450.23, 92, 'Proveedor2', '2023-08-25', 'Almacén C')
# (26, 'Objeto26', 'Jardín', 398.79, 99, 'Proveedor1', '2023-04-09', 'Almacén B')
# (27, 'Producto27', 'Hogar', 253.51, 54, 'Proveedor3', '2023-11-21', 'Almacén A')
# (28, 'Objeto28', 'Deportes', 59.98, 50, 'Proveedor3', '2023-12-18', 'Almacén B')
# (29, 'Artículo29', 'Hogar', 49.65, 45, 'Proveedor1', '2023-12-01', 'Almacén A')
# (30, 'Objeto30', 'Hogar', 289.87, 53, 'Proveedor2', '2023-03-09', 'Almacén C')
# (31, 'Objeto31', 'Deportes', 97.3, 46, 'Proveedor2', '2023-08-14', 'Almacén B')
# (32, 'Objeto32', 'Moda', 400.52, 92, 'Proveedor3', '2023-04-07', 'Almacén B')
# (33, 'Objeto33', 'Electrónica', 228.36, 94, 'Proveedor1', '2023-12-16', 'Almacén C')
# (34, 'Producto34', 'Electrónica', 491.92, 27, 'Proveedor2', '2023-10-01', 'Almacén A')
# (35, 'Objeto35', 'Hogar', 275.85, 68, 'Proveedor1', '2023-08-12', 'Almacén B')
# (36, 'Producto36', 'Hogar', 61.39, 78, 'Proveedor2', '2023-05-02', 'Almacén C')
# (37, 'Artículo37', 'Electrónica', 308.36, 76, 'Proveedor2', '2023-10-28', 'Almacén B')
# (38, 'Producto38', 'Electrónica', 471.75, 7, 'Proveedor1', '2023-02-28', 'Almacén A')
# (39, 'Objeto39', 'Electrónica', 53, 84, 'Proveedor2', '2023-11-23', 'Almacén B')
# (40, 'Objeto40', 'Electrónica', 113.35, 5, 'Proveedor3', '2023-04-15', 'Almacén B')
# (41, 'Artículo41', 'Moda', 135.64, 75, 'Proveedor1', '2023-11-16', 'Almacén B')
# (42, 'Artículo42', 'Hogar', 203.53, 14, 'Proveedor2', '2023-06-03', 'Almacén C')
# (43, 'Objeto43', 'Electrónica', 135.19, 64, 'Proveedor3', '2023-08-27', 'Almacén C')
# (44, 'Objeto44', 'Deportes', 231.66, 8, 'Proveedor3', '2023-09-02', 'Almacén A')
# (45, 'Artículo45', 'Moda', 27.97, 63, 'Proveedor2', '2023-09-27', 'Almacén B')
# (46, 'Objeto46', 'Moda', 349.59, 73, 'Proveedor2', '2023-01-23', 'Almacén A')
# (47, 'Objeto47', 'Jardín', 277.33, 73, 'Proveedor1', '2023-11-26', 'Almacén C')
# (48, 'Objeto48', 'Jardín', 354.84, 1, 'Proveedor2', '2023-02-28', 'Almacén C')
# (49, 'Producto49', 'Deportes', 148.35, 13, 'Proveedor2', '2023-04-11', 'Almacén C')
# (50, 'Producto50', 'Hogar', 130.36, 25, 'Proveedor2', '2023-07-03', 'Almacén B')
# (51, 'Producto51', 'Hogar', 314.2, 78, 'Proveedor3', '2023-03-03', 'Almacén C')
# (52, 'Artículo52', 'Deportes', 348.08, 79, 'Proveedor2', '2023-07-24', 'Almacén C')
# (53, 'Artículo53', 'Electrónica', 139.09, 24, 'Proveedor3', '2023-10-03', 'Almacén B')
# (54, 'Artículo54', 'Deportes', 155.01, 34, 'Proveedor2', '2023-10-05', 'Almacén B')
# (55, 'Producto55', 'Jardín', 77.93, 12, 'Proveedor2', '2023-11-04', 'Almacén B')
# (56, 'Objeto56', 'Hogar', 232.06, 33, 'Proveedor2', '2023-05-23', 'Almacén A')
# (57, 'Artículo57', 'Moda', 133.48, 36, 'Proveedor1', '2023-04-15', 'Almacén C')
# (58, 'Artículo58', 'Moda', 287.19, 29, 'Proveedor3', '2023-01-13', 'Almacén A')
# (59, 'Artículo59', 'Electrónica', 106.86, 22, 'Proveedor3', '2023-08-12', 'Almacén B')
# (60, 'Artículo60', 'Hogar', 486.39, 89, 'Proveedor3', '2023-12-12', 'Almacén C')
# (61, 'Producto61', 'Jardín', 485.71, 96, 'Proveedor3', '2023-01-25', 'Almacén B')
# (62, 'Artículo62', 'Deportes', 386.29, 58, 'Proveedor2', '2023-10-14', 'Almacén B')
# (63, 'Objeto63', 'Hogar', 487.39, 6, 'Proveedor1', '2023-12-04', 'Almacén A')
# (64, 'Artículo64', 'Moda', 175.19, 34, 'Proveedor3', '2023-01-08', 'Almacén C')
# (65, 'Objeto65', 'Jardín', 103.26, 20, 'Proveedor2', '2023-12-23', 'Almacén C')
# (66, 'Objeto66', 'Deportes', 495.34, 77, 'Proveedor2', '2023-03-04', 'Almacén C')
# (67, 'Objeto67', 'Moda', 103.1, 9, 'Proveedor1', '2023-02-10', 'Almacén C')
# (68, 'Objeto68', 'Electrónica', 353.53, 79, 'Proveedor3', '2023-02-14', 'Almacén C')
# (69, 'Producto69', 'Hogar', 281.95, 22, 'Proveedor2', '2023-12-19', 'Almacén C')
# (70, 'Producto70', 'Deportes', 94.76, 73, 'Proveedor2', '2023-06-01', 'Almacén C')
# (71, 'Artículo71', 'Electrónica', 113.04, 64, 'Proveedor1', '2023-02-28', 'Almacén C')
# (72, 'Objeto72', 'Electrónica', 164.72, 14, 'Proveedor3', '2023-06-23', 'Almacén C')
# (73, 'Artículo73', 'Hogar', 394.07, 80, 'Proveedor1', '2023-01-10', 'Almacén B')
# (74, 'Artículo74', 'Deportes', 207.88, 7, 'Proveedor2', '2023-04-16', 'Almacén B')
# (75, 'Artículo75', 'Deportes', 193.18, 45, 'Proveedor2', '2023-01-05', 'Almacén A')
# (76, 'Objeto76', 'Moda', 81.45, 99, 'Proveedor1', '2023-11-25', 'Almacén C')
# (77, 'Objeto77', 'Hogar', 220.14, 32, 'Proveedor3', '2023-10-16', 'Almacén B')
# (78, 'Objeto78', 'Jardín', 323.3, 85, 'Proveedor1', '2023-10-26', 'Almacén A')
# (79, 'Artículo79', 'Hogar', 367.83, 50, 'Proveedor1', '2023-05-04', 'Almacén B')
# (80, 'Artículo80', 'Moda', 212.24, 8, 'Proveedor2', '2023-04-12', 'Almacén B')
# (81, 'Artículo81', 'Electrónica', 247.04, 76, 'Proveedor1', '2023-02-19', 'Almacén B')
# (82, 'Objeto82', 'Jardín', 77.67, 20, 'Proveedor3', '2023-05-27', 'Almacén C')
# (83, 'Producto83', 'Deportes', 226.38, 17, 'Proveedor1', '2023-01-02', 'Almacén B')
# (84, 'Artículo84', 'Deportes', 128.46, 57, 'Proveedor2', '2023-03-17', 'Almacén C')
# (85, 'Objeto85', 'Jardín', 13.94, 66, 'Proveedor3', '2023-03-07', 'Almacén C')
# (86, 'Artículo86', 'Moda', 95.98, 15, 'Proveedor1', '2023-01-19', 'Almacén C')
# (87, 'Objeto87', 'Deportes', 32.14, 71, 'Proveedor1', '2023-08-16', 'Almacén A')
# (88, 'Producto88', 'Hogar', 315.03, 65, 'Proveedor3', '2023-05-07', 'Almacén A')
# (89, 'Objeto89', 'Electrónica', 481.02, 1, 'Proveedor2', '2023-09-10', 'Almacén B')
# (90, 'Producto90', 'Deportes', 210.21, 17, 'Proveedor3', '2023-11-07', 'Almacén C')
# (91, 'Objeto91', 'Jardín', 346.83, 63, 'Proveedor2', '2023-08-11', 'Almacén A')
# (92, 'Producto92', 'Hogar', 212.82, 40, 'Proveedor1', '2023-07-20', 'Almacén C')
# (93, 'Artículo93', 'Deportes', 359.43, 82, 'Proveedor1', '2023-05-22', 'Almacén B')
# (94, 'Artículo94', 'Moda', 39.42, 97, 'Proveedor3', '2023-04-06', 'Almacén B')
# (95, 'Objeto95', 'Jardín', 408.24, 87, 'Proveedor2', '2023-05-13', 'Almacén B')
# (96, 'Producto96', 'Jardín', 358.96, 30, 'Proveedor1', '2023-01-09', 'Almacén B')
# (97, 'Artículo97', 'Jardín', 58, 33, 'Proveedor2', '2023-06-02', 'Almacén B')
# (98, 'Producto98', 'Deportes', 113.72, 53, 'Proveedor2', '2023-11-01', 'Almacén B')
# (99, 'Artículo99', 'Jardín', 122.89, 96, 'Proveedor1', '2023-05-22', 'Almacén C')
# (100, 'Artículo100', 'Moda', 277.69, 75, 'Proveedor2', '2023-09-19', 'Almacén A')
# (101, 'Producto101', 'Moda', 277.04, 47, 'Proveedor1', '2023-07-23', 'Almacén A')
# (102, 'Objeto102', 'Hogar', 109.28, 25, 'Proveedor2', '2023-08-28', 'Almacén A')
# (103, 'Objeto103', 'Moda', 171.17, 9, 'Proveedor3', '2023-06-13', 'Almacén B')
# (104, 'Producto104', 'Jardín', 208.71, 78, 'Proveedor1', '2023-12-25', 'Almacén C')
# (105, 'Producto105', 'Hogar', 51.69, 74, 'Proveedor2', '2023-06-16', 'Almacén C')
# (106, 'Objeto106', 'Hogar', 333.23, 75, 'Proveedor2', '2023-02-17', 'Almacén B')
# (107, 'Artículo107', 'Jardín', 499.75, 2, 'Proveedor1', '2023-09-09', 'Almacén C')
# (108, 'Artículo108', 'Hogar', 312.4, 91, 'Proveedor2', '2023-08-07', 'Almacén C')
# (109, 'Artículo109', 'Moda', 104.9, 26, 'Proveedor1', '2023-11-05', 'Almacén B')
# (110, 'Objeto110', 'Deportes', 421.16, 7, 'Proveedor2', '2023-04-14', 'Almacén A')
# (111, 'Producto111', 'Electrónica', 303, 99, 'Proveedor1', '2023-02-05', 'Almacén A')
# (112, 'Artículo112', 'Moda', 440.67, 43, 'Proveedor2', '2023-02-05', 'Almacén A')
# (113, 'Artículo113', 'Deportes', 24.53, 87, 'Proveedor3', '2023-06-11', 'Almacén C')
# (114, 'Producto114', 'Jardín', 381.26, 69, 'Proveedor3', '2023-05-12', 'Almacén A')
# (115, 'Producto115', 'Deportes', 499.36, 44, 'Proveedor1', '2023-07-16', 'Almacén B')
# (116, 'Producto116', 'Hogar', 53.38, 69, 'Proveedor3', '2023-03-14', 'Almacén A')
# (117, 'Producto117', 'Electrónica', 275.14, 39, 'Proveedor1', '2023-08-02', 'Almacén B')
# (118, 'Artículo118', 'Deportes', 395.16, 29, 'Proveedor2', '2023-07-18', 'Almacén A')
# (119, 'Producto119', 'Hogar', 457.2, 5, 'Proveedor3', '2023-01-02', 'Almacén C')
# (120, 'Artículo120', 'Jardín', 248.75, 44, 'Proveedor1', '2023-10-17', 'Almacén B')
# (121, 'Producto121', 'Moda', 454.49, 24, 'Proveedor3', '2023-12-11', 'Almacén B')
# (122, 'Producto122', 'Hogar', 498.7, 61, 'Proveedor2', '2023-03-23', 'Almacén A')
# (123, 'Producto123', 'Electrónica', 157.49, 100, 'Proveedor2', '2023-09-20', 'Almacén A')
# (124, 'Objeto124', 'Jardín', 176.41, 69, 'Proveedor2', '2023-12-08', 'Almacén B')
# (125, 'Objeto125', 'Electrónica', 23.14, 29, 'Proveedor3', '2023-09-08', 'Almacén C')
# (126, 'Artículo126', 'Deportes', 247.88, 99, 'Proveedor1', '2023-11-02', 'Almacén A')
# (127, 'Artículo127', 'Deportes', 236.74, 15, 'Proveedor2', '2023-09-06', 'Almacén B')
# (128, 'Artículo128', 'Moda', 459.8, 73, 'Proveedor2', '2023-07-06', 'Almacén C')
# (129, 'Objeto129', 'Hogar', 465.11, 87, 'Proveedor2', '2023-05-07', 'Almacén B')
# (130, 'Artículo130', 'Hogar', 241.12, 100, 'Proveedor2', '2023-12-13', 'Almacén A')
# (131, 'Artículo131', 'Electrónica', 302.35, 18, 'Proveedor1', '2023-01-14', 'Almacén A')
# (132, 'Artículo132', 'Deportes', 137.51, 19, 'Proveedor2', '2023-09-21', 'Almacén A')
# (133, 'Producto133', 'Hogar', 62.32, 95, 'Proveedor1', '2023-06-28', 'Almacén C')
# (134, 'Artículo134', 'Moda', 462.71, 96, 'Proveedor2', '2023-02-08', 'Almacén B')
# (135, 'Producto135', 'Hogar', 139.69, 68, 'Proveedor3', '2023-08-10', 'Almacén C')
# (136, 'Producto136', 'Hogar', 78.85, 43, 'Proveedor1', '2023-12-19', 'Almacén C')
# (137, 'Artículo137', 'Deportes', 364.26, 35, 'Proveedor3', '2023-06-16', 'Almacén C')
# (138, 'Producto138', 'Deportes', 24.6, 30, 'Proveedor2', '2023-09-18', 'Almacén C')
# (139, 'Producto139', 'Jardín', 295.01, 25, 'Proveedor3', '2023-10-06', 'Almacén A')
# (140, 'Artículo140', 'Jardín', 113.64, 65, 'Proveedor3', '2023-01-18', 'Almacén B')
# (141, 'Producto141', 'Moda', 202.88, 90, 'Proveedor1', '2023-10-12', 'Almacén A')
# (142, 'Producto142', 'Deportes', 293.28, 42, 'Proveedor3', '2023-03-21', 'Almacén C')
# (143, 'Objeto143', 'Jardín', 224.36, 28, 'Proveedor2', '2023-08-22', 'Almacén B')
# (144, 'Objeto144', 'Deportes', 228.38, 26, 'Proveedor3', '2023-04-07', 'Almacén A')
# (145, 'Producto145', 'Electrónica', 428.51, 61, 'Proveedor1', '2023-05-27', 'Almacén A')
# (146, 'Artículo146', 'Jardín', 242.07, 44, 'Proveedor3', '2023-11-16', 'Almacén A')
# (147, 'Objeto147', 'Moda', 282.48, 17, 'Proveedor3', '2023-06-24', 'Almacén C')
# (148, 'Objeto148', 'Deportes', 363.02, 39, 'Proveedor1', '2023-12-11', 'Almacén B')
# (149, 'Artículo149', 'Deportes', 491.05, 19, 'Proveedor1', '2023-09-24', 'Almacén C')
# (150, 'Objeto150', 'Jardín', 131.64, 48, 'Proveedor2', '2023-05-14', 'Almacén C')
# (151, 'Producto151', 'Moda', 331.08, 69, 'Proveedor3', '2023-02-12', 'Almacén A')
# (152, 'Objeto152', 'Deportes', 482.98, 59, 'Proveedor3', '2023-06-15', 'Almacén C')
# (153, 'Producto153', 'Hogar', 309.87, 52, 'Proveedor3', '2023-07-08', 'Almacén B')
# (154, 'Producto154', 'Moda', 485.97, 43, 'Proveedor2', '2023-08-01', 'Almacén C')
# (155, 'Producto155', 'Hogar', 432.4, 78, 'Proveedor3', '2023-11-27', 'Almacén B')
# (156, 'Producto156', 'Jardín', 122.72, 94, 'Proveedor2', '2023-07-17', 'Almacén A')
# (157, 'Producto157', 'Moda', 61.04, 17, 'Proveedor3', '2023-09-25', 'Almacén A')
# (158, 'Producto158', 'Moda', 301.72, 33, 'Proveedor2', '2023-10-10', 'Almacén C')
# (159, 'Objeto159', 'Moda', 29.99, 49, 'Proveedor3', '2023-12-12', 'Almacén A')
# (160, 'Artículo160', 'Jardín', 193.5, 72, 'Proveedor1', '2023-09-09', 'Almacén B')
# (161, 'Producto161', 'Hogar', 395.8, 39, 'Proveedor1', '2023-08-03', 'Almacén B')
# (162, 'Artículo162', 'Moda', 91.68, 48, 'Proveedor3', '2023-10-19', 'Almacén B')
# (163, 'Objeto163', 'Moda', 413.2, 19, 'Proveedor1', '2023-09-10', 'Almacén A')
# (164, 'Artículo164', 'Electrónica', 493.25, 21, 'Proveedor2', '2023-05-11', 'Almacén C')
# (165, 'Artículo165', 'Jardín', 18.42, 99, 'Proveedor1', '2023-10-09', 'Almacén C')
# (166, 'Objeto166', 'Hogar', 257.11, 89, 'Proveedor2', '2023-08-23', 'Almacén A')
# (167, 'Artículo167', 'Jardín', 139.97, 14, 'Proveedor1', '2023-10-02', 'Almacén A')
# (168, 'Artículo168', 'Jardín', 393.13, 90, 'Proveedor2', '2023-05-14', 'Almacén B')
# (169, 'Artículo169', 'Jardín', 341.6, 34, 'Proveedor2', '2023-12-13', 'Almacén A')
# (170, 'Producto170', 'Electrónica', 84.81, 82, 'Proveedor1', '2023-10-19', 'Almacén B')
# (171, 'Objeto171', 'Hogar', 200.01, 20, 'Proveedor2', '2023-04-28', 'Almacén A')
# (172, 'Producto172', 'Moda', 453.61, 29, 'Proveedor2', '2023-05-03', 'Almacén C')
# (173, 'Producto173', 'Deportes', 474.42, 3, 'Proveedor3', '2023-04-04', 'Almacén A')
# (174, 'Objeto174', 'Electrónica', 311.27, 28, 'Proveedor2', '2023-08-25', 'Almacén B')
# (175, 'Producto175', 'Jardín', 446.72, 68, 'Proveedor2', '2023-07-28', 'Almacén C')
# (176, 'Objeto176', 'Hogar', 32.13, 88, 'Proveedor1', '2023-10-26', 'Almacén B')
# (177, 'Objeto177', 'Deportes', 471.94, 17, 'Proveedor2', '2023-11-21', 'Almacén C')
# (178, 'Artículo178', 'Moda', 330.74, 75, 'Proveedor1', '2023-09-15', 'Almacén C')
# (179, 'Producto179', 'Hogar', 245.45, 62, 'Proveedor1', '2023-09-13', 'Almacén C')
# (180, 'Artículo180', 'Moda', 293.78, 83, 'Proveedor2', '2023-10-08', 'Almacén B')
# (181, 'Producto181', 'Electrónica', 317.88, 18, 'Proveedor1', '2023-02-07', 'Almacén C')
# (182, 'Objeto182', 'Hogar', 84.55, 25, 'Proveedor2', '2023-12-05', 'Almacén C')
# (183, 'Objeto183', 'Jardín', 295.75, 44, 'Proveedor2', '2023-01-12', 'Almacén C')
# (184, 'Producto184', 'Deportes', 428.76, 56, 'Proveedor1', '2023-10-16', 'Almacén B')
# (185, 'Producto185', 'Deportes', 284.82, 78, 'Proveedor3', '2023-05-13', 'Almacén B')
# (186, 'Producto186', 'Deportes', 287.08, 24, 'Proveedor3', '2023-08-08', 'Almacén A')
# (187, 'Objeto187', 'Electrónica', 481.01, 9, 'Proveedor2', '2023-11-09', 'Almacén B')
# (188, 'Producto188', 'Electrónica', 198.08, 88, 'Proveedor1', '2023-07-19', 'Almacén B')
# (189, 'Producto189', 'Jardín', 362.89, 52, 'Proveedor1', '2023-06-23', 'Almacén B')
# (190, 'Producto190', 'Jardín', 193.25, 60, 'Proveedor2', '2023-09-27', 'Almacén C')
# (191, 'Producto191', 'Moda', 21.67, 6, 'Proveedor3', '2023-06-07', 'Almacén A')
# (192, 'Producto192', 'Deportes', 163.74, 35, 'Proveedor3', '2023-05-09', 'Almacén C')
# (193, 'Artículo193', 'Deportes', 118.76, 60, 'Proveedor2', '2023-12-10', 'Almacén C')
# (194, 'Artículo194', 'Hogar', 250.45, 36, 'Proveedor3', '2023-06-15', 'Almacén B')
# (195, 'Objeto195', 'Hogar', 61.12, 54, 'Proveedor1', '2023-04-12', 'Almacén A')
# (196, 'Artículo196', 'Jardín', 210.38, 77, 'Proveedor3', '2023-01-20', 'Almacén C')
# (197, 'Artículo197', 'Hogar', 314.99, 99, 'Proveedor1', '2023-03-27', 'Almacén B')
# (198, 'Producto198', 'Moda', 296.7, 64, 'Proveedor1', '2023-06-04', 'Almacén B')
# (199, 'Producto199', 'Jardín', 181.25, 46, 'Proveedor1', '2023-09-05', 'Almacén B')
# (200, 'Objeto200', 'Jardín', 494.81, 39, 'Proveedor2', '2023-09-16', 'Almacén B')
# (201, 'Artículo201', 'Electrónica', 453.96, 31, 'Proveedor3', '2023-06-02', 'Almacén A')
# (202, 'Artículo202', 'Deportes', 31.35, 91, 'Proveedor3', '2023-12-02', 'Almacén B')
# (203, 'Objeto203', 'Hogar', 208.47, 6, 'Proveedor2', '2023-04-11', 'Almacén A')
# (204, 'Producto204', 'Electrónica', 200.54, 44, 'Proveedor3', '2023-01-25', 'Almacén C')
# (205, 'Producto205', 'Deportes', 398.45, 31, 'Proveedor1', '2023-04-26', 'Almacén B')
# (206, 'Producto206', 'Electrónica', 213.8, 29, 'Proveedor1', '2023-10-27', 'Almacén A')
# (207, 'Producto207', 'Moda', 231.17, 100, 'Proveedor1', '2023-06-08', 'Almacén B')
# (208, 'Objeto208', 'Jardín', 493.12, 19, 'Proveedor3', '2023-02-19', 'Almacén B')
# (209, 'Producto209', 'Hogar', 355.4, 33, 'Proveedor3', '2023-03-18', 'Almacén C')
# (210, 'Artículo210', 'Hogar', 208.54, 23, 'Proveedor2', '2023-05-01', 'Almacén B')
# (211, 'Artículo211', 'Hogar', 326.97, 59, 'Proveedor1', '2023-07-26', 'Almacén B')
# (212, 'Artículo212', 'Electrónica', 272.63, 97, 'Proveedor1', '2023-11-06', 'Almacén B')
# (213, 'Producto213', 'Moda', 425.52, 70, 'Proveedor3', '2023-10-10', 'Almacén C')
# (214, 'Objeto214', 'Deportes', 60.35, 2, 'Proveedor1', '2023-10-19', 'Almacén B')
# (215, 'Objeto215', 'Deportes', 199.66, 43, 'Proveedor3', '2023-01-02', 'Almacén A')
# (216, 'Artículo216', 'Hogar', 252.52, 82, 'Proveedor1', '2023-12-19', 'Almacén C')
# (217, 'Artículo217', 'Hogar', 442.54, 22, 'Proveedor3', '2023-11-07', 'Almacén A')
# (218, 'Objeto218', 'Deportes', 297.28, 32, 'Proveedor2', '2023-12-23', 'Almacén C')
# (219, 'Artículo219', 'Jardín', 497.8, 40, 'Proveedor1', '2023-07-25', 'Almacén C')
# (220, 'Producto220', 'Deportes', 449.57, 19, 'Proveedor3', '2023-08-12', 'Almacén C')
# (221, 'Artículo221', 'Electrónica', 379.78, 40, 'Proveedor2', '2023-01-01', 'Almacén A')
# (222, 'Artículo222', 'Deportes', 41.75, 90, 'Proveedor3', '2023-04-04', 'Almacén B')
# (223, 'Producto223', 'Deportes', 112.41, 78, 'Proveedor2', '2023-08-18', 'Almacén B')
# (224, 'Producto224', 'Electrónica', 100.16, 53, 'Proveedor1', '2023-03-23', 'Almacén A')
# (225, 'Artículo225', 'Hogar', 347.22, 3, 'Proveedor3', '2023-01-17', 'Almacén B')
# (226, 'Producto226', 'Jardín', 434.54, 11, 'Proveedor3', '2023-04-09', 'Almacén A')
# (227, 'Artículo227', 'Hogar', 340.53, 12, 'Proveedor2', '2023-08-23', 'Almacén A')
# (228, 'Producto228', 'Deportes', 242.94, 19, 'Proveedor2', '2023-10-25', 'Almacén B')
# (229, 'Artículo229', 'Electrónica', 44, 63, 'Proveedor1', '2023-05-02', 'Almacén C')
# (230, 'Artículo230', 'Electrónica', 238.62, 9, 'Proveedor2', '2023-04-10', 'Almacén C')
# (231, 'Producto231', 'Deportes', 466.98, 9, 'Proveedor1', '2023-01-05', 'Almacén C')
# (232, 'Objeto232', 'Deportes', 125.15, 9, 'Proveedor1', '2023-08-16', 'Almacén A')
# (233, 'Producto233', 'Jardín', 415.99, 38, 'Proveedor1', '2023-11-11', 'Almacén A')
# (234, 'Producto234', 'Hogar', 75.86, 27, 'Proveedor3', '2023-05-04', 'Almacén A')
# (235, 'Producto235', 'Electrónica', 280.36, 37, 'Proveedor3', '2023-01-16', 'Almacén A')
# (236, 'Objeto236', 'Jardín', 247.8, 70, 'Proveedor3', '2023-12-20', 'Almacén C')
# (237, 'Producto237', 'Electrónica', 113.7, 2, 'Proveedor2', '2023-02-01', 'Almacén A')
# (238, 'Artículo238', 'Deportes', 369.44, 99, 'Proveedor2', '2023-02-19', 'Almacén A')
# (239, 'Objeto239', 'Hogar', 30.53, 12, 'Proveedor1', '2023-05-06', 'Almacén C')
# (240, 'Producto240', 'Hogar', 220.08, 86, 'Proveedor1', '2023-03-12', 'Almacén B')
# (241, 'Objeto241', 'Jardín', 183.6, 31, 'Proveedor1', '2023-03-17', 'Almacén A')
# (242, 'Objeto242', 'Jardín', 263.36, 3, 'Proveedor3', '2023-10-25', 'Almacén A')
# (243, 'Producto243', 'Hogar', 247.89, 52, 'Proveedor1', '2023-06-11', 'Almacén C')
# (244, 'Artículo244', 'Electrónica', 269.27, 1, 'Proveedor2', '2023-11-20', 'Almacén B')
# (245, 'Artículo245', 'Electrónica', 443.86, 59, 'Proveedor1', '2023-04-06', 'Almacén B')
# (246, 'Producto246', 'Electrónica', 138.78, 69, 'Proveedor2', '2023-08-27', 'Almacén C')
# (247, 'Objeto247', 'Jardín', 398.63, 89, 'Proveedor3', '2023-11-01', 'Almacén C')
# (248, 'Objeto248', 'Moda', 54.84, 2, 'Proveedor1', '2023-07-27', 'Almacén B')
# (249, 'Objeto249', 'Electrónica', 85.58, 12, 'Proveedor1', '2023-12-07', 'Almacén A')
# (250, 'Objeto250', 'Hogar', 260.77, 57, 'Proveedor2', '2023-10-03', 'Almacén A')
# (251, 'Artículo251', 'Deportes', 217.43, 75, 'Proveedor2', '2023-08-07', 'Almacén B')
# (252, 'Producto252', 'Jardín', 85, 57, 'Proveedor1', '2023-08-20', 'Almacén C')
# (253, 'Artículo253', 'Electrónica', 449.65, 32, 'Proveedor2', '2023-10-20', 'Almacén C')
# (254, 'Objeto254', 'Electrónica', 195.71, 15, 'Proveedor1', '2023-12-23', 'Almacén A')
# (255, 'Artículo255', 'Jardín', 330.97, 40, 'Proveedor1', '2023-09-03', 'Almacén A')
# (256, 'Objeto256', 'Deportes', 217.48, 90, 'Proveedor1', '2023-07-13', 'Almacén C')
# (257, 'Objeto257', 'Deportes', 266.97, 24, 'Proveedor1', '2023-08-25', 'Almacén C')
# (258, 'Artículo258', 'Moda', 445.1, 58, 'Proveedor3', '2023-07-17', 'Almacén C')
# (259, 'Artículo259', 'Hogar', 358.31, 1, 'Proveedor2', '2023-04-19', 'Almacén B')
# (260, 'Producto260', 'Electrónica', 48.89, 27, 'Proveedor3', '2023-10-18', 'Almacén B')
# (261, 'Artículo261', 'Electrónica', 400, 3, 'Proveedor2', '2023-03-02', 'Almacén B')
# (262, 'Objeto262', 'Electrónica', 439.62, 80, 'Proveedor1', '2023-11-23', 'Almacén B')
# (263, 'Producto263', 'Deportes', 265.09, 40, 'Proveedor3', '2023-07-05', 'Almacén B')
# (264, 'Objeto264', 'Jardín', 464.49, 15, 'Proveedor2', '2023-03-07', 'Almacén B')
# (265, 'Artículo265', 'Deportes', 477.74, 98, 'Proveedor3', '2023-03-22', 'Almacén C')
# (266, 'Objeto266', 'Jardín', 452.15, 54, 'Proveedor1', '2023-01-19', 'Almacén A')
# (267, 'Artículo267', 'Deportes', 252.57, 90, 'Proveedor1', '2023-01-03', 'Almacén A')
# (268, 'Producto268', 'Moda', 391.39, 21, 'Proveedor2', '2023-01-06', 'Almacén A')
# (269, 'Producto269', 'Electrónica', 299.74, 25, 'Proveedor2', '2023-07-15', 'Almacén C')
# (270, 'Producto270', 'Deportes', 209.3, 30, 'Proveedor3', '2023-06-03', 'Almacén B')
# (271, 'Objeto271', 'Hogar', 275.53, 93, 'Proveedor3', '2023-04-12', 'Almacén A')
# (272, 'Objeto272', 'Electrónica', 397.97, 61, 'Proveedor3', '2023-03-19', 'Almacén B')
# (273, 'Producto273', 'Moda', 144.05, 92, 'Proveedor2', '2023-03-16', 'Almacén C')
# (274, 'Artículo274', 'Jardín', 409.03, 54, 'Proveedor2', '2023-06-09', 'Almacén B')
# (275, 'Producto275', 'Deportes', 278.9, 61, 'Proveedor2', '2023-02-27', 'Almacén C')
# (276, 'Objeto276', 'Hogar', 445.19, 90, 'Proveedor3', '2023-06-26', 'Almacén B')
# (277, 'Artículo277', 'Hogar', 306.73, 32, 'Proveedor3', '2023-08-03', 'Almacén A')
# (278, 'Artículo278', 'Hogar', 126.06, 33, 'Proveedor2', '2023-11-10', 'Almacén B')
# (279, 'Objeto279', 'Electrónica', 136.18, 17, 'Proveedor2', '2023-02-23', 'Almacén A')
# (280, 'Artículo280', 'Hogar', 410.31, 9, 'Proveedor2', '2023-12-09', 'Almacén A')
# (281, 'Objeto281', 'Jardín', 207.62, 15, 'Proveedor3', '2023-09-17', 'Almacén B')
# (282, 'Producto282', 'Deportes', 49.75, 42, 'Proveedor3', '2023-12-13', 'Almacén C')
# (283, 'Producto283', 'Deportes', 268.23, 24, 'Proveedor3', '2023-04-12', 'Almacén B')
# (284, 'Objeto284', 'Deportes', 435.95, 97, 'Proveedor3', '2023-04-22', 'Almacén B')
# (285, 'Artículo285', 'Electrónica', 316.24, 15, 'Proveedor2', '2023-12-19', 'Almacén C')
# (286, 'Producto286', 'Deportes', 341.89, 52, 'Proveedor1', '2023-10-26', 'Almacén C')
# (287, 'Artículo287', 'Moda', 430.1, 79, 'Proveedor1', '2023-02-03', 'Almacén A')
# (288, 'Artículo288', 'Deportes', 410.42, 73, 'Proveedor1', '2023-05-16', 'Almacén A')
# (289, 'Artículo289', 'Jardín', 232.98, 82, 'Proveedor2', '2023-12-12', 'Almacén A')
# (290, 'Producto290', 'Electrónica', 414.08, 90, 'Proveedor3', '2023-06-27', 'Almacén A')
# (291, 'Artículo291', 'Electrónica', 108.44, 33, 'Proveedor2', '2023-10-19', 'Almacén C')
# (292, 'Producto292', 'Deportes', 92.3, 5, 'Proveedor3', '2023-07-01', 'Almacén B')
# (293, 'Producto293', 'Jardín', 363.65, 93, 'Proveedor2', '2023-07-02', 'Almacén B')
# (294, 'Artículo294', 'Deportes', 354.35, 46, 'Proveedor3', '2023-09-05', 'Almacén C')
# (295, 'Objeto295', 'Electrónica', 353.44, 51, 'Proveedor3', '2023-07-23', 'Almacén B')
# (296, 'Producto296', 'Jardín', 314.43, 55, 'Proveedor1', '2023-04-24', 'Almacén C')
# (297, 'Objeto297', 'Hogar', 206.27, 69, 'Proveedor2', '2023-02-19', 'Almacén C')
# (298, 'Producto298', 'Electrónica', 171.66, 58, 'Proveedor3', '2023-09-19', 'Almacén A')
# (299, 'Objeto299', 'Electrónica', 471.42, 2, 'Proveedor1', '2023-11-23', 'Almacén C')
# (300, 'Artículo300', 'Deportes', 70.73, 61, 'Proveedor3', '2023-11-22', 'Almacén B')
# (301, 'Artículo301', 'Deportes', 444.58, 32, 'Proveedor1', '2023-07-10', 'Almacén C')
# (302, 'Objeto302', 'Electrónica', 183.9, 3, 'Proveedor1', '2023-02-02', 'Almacén C')
# (303, 'Producto303', 'Electrónica', 387.94, 53, 'Proveedor3', '2023-01-24', 'Almacén A')
# (304, 'Objeto304', 'Hogar', 202.5, 47, 'Proveedor1', '2023-04-02', 'Almacén A')
# (305, 'Objeto305', 'Jardín', 282.82, 10, 'Proveedor3', '2023-06-03', 'Almacén A')
# (306, 'Objeto306', 'Electrónica', 182.93, 67, 'Proveedor2', '2023-12-05', 'Almacén C')
# (307, 'Producto307', 'Hogar', 193.78, 36, 'Proveedor3', '2023-09-10', 'Almacén A')
# (308, 'Producto308', 'Electrónica', 492.86, 95, 'Proveedor3', '2023-06-14', 'Almacén B')
# (309, 'Objeto309', 'Deportes', 495.68, 34, 'Proveedor1', '2023-08-21', 'Almacén C')
# (310, 'Artículo310', 'Moda', 323.32, 88, 'Proveedor1', '2023-02-06', 'Almacén C')
# (311, 'Objeto311', 'Moda', 105.48, 58, 'Proveedor2', '2023-08-27', 'Almacén C')
# (312, 'Producto312', 'Deportes', 138.24, 1, 'Proveedor1', '2023-05-11', 'Almacén B')
# (313, 'Artículo313', 'Hogar', 154.71, 19, 'Proveedor3', '2023-05-11', 'Almacén C')
# (314, 'Artículo314', 'Jardín', 177.98, 30, 'Proveedor2', '2023-09-17', 'Almacén A')
# (315, 'Producto315', 'Deportes', 222.58, 33, 'Proveedor2', '2023-03-12', 'Almacén B')
# (316, 'Artículo316', 'Jardín', 479.12, 19, 'Proveedor1', '2023-01-16', 'Almacén B')
# (317, 'Producto317', 'Hogar', 184.83, 83, 'Proveedor2', '2023-04-14', 'Almacén A')
# (318, 'Producto318', 'Hogar', 241.52, 8, 'Proveedor2', '2023-01-05', 'Almacén A')
# (319, 'Artículo319', 'Jardín', 496.93, 14, 'Proveedor3', '2023-01-23', 'Almacén C')
# (320, 'Producto320', 'Jardín', 158.52, 43, 'Proveedor1', '2023-09-25', 'Almacén C')
# (321, 'Producto321', 'Electrónica', 220.2, 80, 'Proveedor2', '2023-08-09', 'Almacén C')
# (322, 'Artículo322', 'Hogar', 299.81, 90, 'Proveedor2', '2023-08-06', 'Almacén C')
# (323, 'Objeto323', 'Jardín', 244.5, 52, 'Proveedor2', '2023-07-02', 'Almacén A')
# (324, 'Producto324', 'Hogar', 384.42, 100, 'Proveedor1', '2023-01-01', 'Almacén A')
# (325, 'Producto325', 'Jardín', 115.53, 53, 'Proveedor3', '2023-01-20', 'Almacén C')
# (326, 'Artículo326', 'Electrónica', 192.99, 28, 'Proveedor1', '2023-06-09', 'Almacén B')
# (327, 'Artículo327', 'Deportes', 149.53, 59, 'Proveedor3', '2023-11-06', 'Almacén C')
# (328, 'Objeto328', 'Hogar', 217.93, 24, 'Proveedor1', '2023-06-27', 'Almacén A')
# (329, 'Artículo329', 'Deportes', 259.01, 76, 'Proveedor3', '2023-06-20', 'Almacén B')
# (330, 'Artículo330', 'Jardín', 413.71, 86, 'Proveedor3', '2023-11-28', 'Almacén B')
# (331, 'Objeto331', 'Deportes', 186.11, 79, 'Proveedor3', '2023-02-25', 'Almacén A')
# (332, 'Objeto332', 'Deportes', 194.22, 29, 'Proveedor3', '2023-09-10', 'Almacén C')
# (333, 'Artículo333', 'Electrónica', 481.42, 53, 'Proveedor1', '2023-08-17', 'Almacén A')
# (334, 'Artículo334', 'Moda', 110.5, 91, 'Proveedor3', '2023-02-22', 'Almacén C')
# (335, 'Objeto335', 'Hogar', 233.61, 83, 'Proveedor2', '2023-05-06', 'Almacén A')
# (336, 'Objeto336', 'Jardín', 73.87, 7, 'Proveedor2', '2023-07-18', 'Almacén C')
# (337, 'Artículo337', 'Moda', 279.9, 98, 'Proveedor2', '2023-11-21', 'Almacén B')
# (338, 'Producto338', 'Deportes', 468.8, 83, 'Proveedor3', '2023-07-28', 'Almacén C')
# (339, 'Producto339', 'Moda', 187.24, 34, 'Proveedor3', '2023-06-11', 'Almacén B')
# (340, 'Producto340', 'Deportes', 260.62, 100, 'Proveedor1', '2023-08-19', 'Almacén B')
# (341, 'Objeto341', 'Electrónica', 454.06, 30, 'Proveedor3', '2023-12-11', 'Almacén C')
# (342, 'Artículo342', 'Moda', 387.17, 41, 'Proveedor1', '2023-05-05', 'Almacén C')
# (343, 'Producto343', 'Electrónica', 105.53, 68, 'Proveedor2', '2023-07-05', 'Almacén A')
# (344, 'Objeto344', 'Hogar', 169.04, 97, 'Proveedor3', '2023-11-14', 'Almacén B')
# (345, 'Objeto345', 'Moda', 307.13, 25, 'Proveedor2', '2023-03-11', 'Almacén C')
# (346, 'Producto346', 'Moda', 247.79, 90, 'Proveedor3', '2023-07-07', 'Almacén C')
# (347, 'Producto347', 'Electrónica', 85.53, 2, 'Proveedor1', '2023-08-12', 'Almacén B')
# (348, 'Objeto348', 'Hogar', 16.4, 8, 'Proveedor3', '2023-12-17', 'Almacén A')
# (349, 'Artículo349', 'Hogar', 386.26, 65, 'Proveedor1', '2023-09-07', 'Almacén B')
# (350, 'Producto350', 'Jardín', 243.63, 24, 'Proveedor3', '2023-10-03', 'Almacén A')
# (351, 'Producto351', 'Deportes', 111.35, 61, 'Proveedor3', '2023-07-15', 'Almacén A')
# (352, 'Producto352', 'Jardín', 271.41, 69, 'Proveedor3', '2023-09-16', 'Almacén B')
# (353, 'Objeto353', 'Jardín', 363.04, 71, 'Proveedor3', '2023-03-15', 'Almacén C')
# (354, 'Producto354', 'Hogar', 99.4, 10, 'Proveedor1', '2023-10-01', 'Almacén A')
# (355, 'Producto355', 'Hogar', 463.45, 95, 'Proveedor3', '2023-07-08', 'Almacén C')
# (356, 'Objeto356', 'Deportes', 10.84, 60, 'Proveedor3', '2023-06-21', 'Almacén B')
# (357, 'Objeto357', 'Moda', 136.84, 93, 'Proveedor1', '2023-06-09', 'Almacén A')
# (358, 'Artículo358', 'Hogar', 301.08, 5, 'Proveedor1', '2023-01-14', 'Almacén C')
# (359, 'Producto359', 'Deportes', 136.56, 100, 'Proveedor2', '2023-09-17', 'Almacén B')
# (360, 'Producto360', 'Moda', 82.44, 67, 'Proveedor1', '2023-02-05', 'Almacén B')
# (361, 'Producto361', 'Deportes', 252.65, 97, 'Proveedor3', '2023-01-05', 'Almacén A')
# (362, 'Artículo362', 'Moda', 264.66, 80, 'Proveedor1', '2023-12-26', 'Almacén C')
# (363, 'Artículo363', 'Hogar', 206.37, 28, 'Proveedor2', '2023-03-01', 'Almacén A')
# (364, 'Artículo364', 'Hogar', 156.75, 95, 'Proveedor2', '2023-01-04', 'Almacén C')
# (365, 'Artículo365', 'Deportes', 67.99, 7, 'Proveedor3', '2023-02-19', 'Almacén A')
# (366, 'Producto366', 'Hogar', 392.92, 93, 'Proveedor1', '2023-05-09', 'Almacén A')
# (367, 'Objeto367', 'Moda', 150.22, 88, 'Proveedor2', '2023-03-03', 'Almacén C')
# (368, 'Producto368', 'Moda', 90.19, 29, 'Proveedor2', '2023-05-28', 'Almacén A')
# (369, 'Artículo369', 'Jardín', 367.88, 66, 'Proveedor2', '2023-06-08', 'Almacén C')
# (370, 'Producto370', 'Electrónica', 439.54, 79, 'Proveedor2', '2023-07-15', 'Almacén A')
# (371, 'Producto371', 'Deportes', 48.03, 6, 'Proveedor1', '2023-08-27', 'Almacén A')
# (372, 'Artículo372', 'Deportes', 455.03, 36, 'Proveedor2', '2023-11-11', 'Almacén A')
# (373, 'Artículo373', 'Electrónica', 374.19, 2, 'Proveedor1', '2023-11-01', 'Almacén A')
# (374, 'Artículo374', 'Jardín', 109.76, 35, 'Proveedor1', '2023-09-08', 'Almacén C')
# (375, 'Artículo375', 'Deportes', 447.09, 86, 'Proveedor2', '2023-04-01', 'Almacén C')
# (376, 'Artículo376', 'Deportes', 296.05, 12, 'Proveedor3', '2023-11-28', 'Almacén B')
# (377, 'Artículo377', 'Jardín', 403.09, 39, 'Proveedor3', '2023-03-05', 'Almacén B')
# (378, 'Artículo378', 'Moda', 274.1, 87, 'Proveedor2', '2023-03-13', 'Almacén A')
# (379, 'Objeto379', 'Moda', 140.97, 85, 'Proveedor2', '2023-10-16', 'Almacén B')
# (380, 'Producto380', 'Moda', 359.3, 27, 'Proveedor2', '2023-04-14', 'Almacén B')
# (381, 'Objeto381', 'Electrónica', 84.81, 8, 'Proveedor3', '2023-11-09', 'Almacén A')
# (382, 'Artículo382', 'Jardín', 237.61, 29, 'Proveedor3', '2023-01-01', 'Almacén C')
# (383, 'Objeto383', 'Moda', 206.56, 74, 'Proveedor2', '2023-10-20', 'Almacén B')
# (384, 'Producto384', 'Moda', 168.03, 2, 'Proveedor3', '2023-02-15', 'Almacén B')
# (385, 'Producto385', 'Jardín', 110.15, 59, 'Proveedor1', '2023-12-11', 'Almacén A')
# (386, 'Artículo386', 'Electrónica', 278.28, 96, 'Proveedor3', '2023-07-02', 'Almacén B')
# (387, 'Producto387', 'Electrónica', 356.79, 77, 'Proveedor2', '2023-02-07', 'Almacén C')
# (388, 'Objeto388', 'Moda', 458.21, 69, 'Proveedor3', '2023-04-05', 'Almacén C')
# (389, 'Artículo389', 'Electrónica', 183.31, 69, 'Proveedor2', '2023-06-01', 'Almacén C')
# (390, 'Producto390', 'Deportes', 68.53, 6, 'Proveedor3', '2023-05-06', 'Almacén A')
# (391, 'Objeto391', 'Jardín', 221.9, 91, 'Proveedor1', '2023-07-28', 'Almacén C')
# (392, 'Objeto392', 'Moda', 169.27, 16, 'Proveedor1', '2023-12-23', 'Almacén C')
# (393, 'Artículo393', 'Jardín', 322.27, 38, 'Proveedor2', '2023-11-06', 'Almacén C')
# (394, 'Artículo394', 'Moda', 489.95, 96, 'Proveedor3', '2023-09-24', 'Almacén A')
# (395, 'Artículo395', 'Jardín', 123.98, 98, 'Proveedor3', '2023-10-17', 'Almacén B')
# (396, 'Objeto396', 'Moda', 475.7, 14, 'Proveedor2', '2023-02-25', 'Almacén A')
# (397, 'Artículo397', 'Moda', 163.19, 97, 'Proveedor1', '2023-10-12', 'Almacén A')
# (398, 'Objeto398', 'Hogar', 401.73, 86, 'Proveedor2', '2023-02-11', 'Almacén B')
# (399, 'Artículo399', 'Jardín', 397.94, 35, 'Proveedor3', '2023-12-22', 'Almacén A')
# (400, 'Producto400', 'Deportes', 382.34, 24, 'Proveedor3', '2023-04-23', 'Almacén B')
# (401, 'Objeto401', 'Jardín', 162.29, 82, 'Proveedor3', '2023-02-15', 'Almacén B')
# (402, 'Artículo402', 'Electrónica', 14.08, 75, 'Proveedor1', '2023-08-10', 'Almacén B')
# (403, 'Objeto403', 'Moda', 248.49, 38, 'Proveedor3', '2023-07-05', 'Almacén A')
# (404, 'Producto404', 'Moda', 22.78, 95, 'Proveedor3', '2023-06-10', 'Almacén A')
# (405, 'Objeto405', 'Deportes', 284.25, 32, 'Proveedor2', '2023-06-14', 'Almacén A')
# (406, 'Producto406', 'Electrónica', 395.75, 49, 'Proveedor3', '2023-03-26', 'Almacén A')
# (407, 'Producto407', 'Electrónica', 471.84, 77, 'Proveedor3', '2023-05-19', 'Almacén A')
# (408, 'Artículo408', 'Electrónica', 308.1, 4, 'Proveedor3', '2023-03-22', 'Almacén C')
# (409, 'Objeto409', 'Jardín', 232.74, 56, 'Proveedor2', '2023-11-05', 'Almacén B')
# (410, 'Objeto410', 'Electrónica', 232.96, 21, 'Proveedor3', '2023-06-05', 'Almacén A')
# (411, 'Objeto411', 'Electrónica', 263.22, 65, 'Proveedor1', '2023-11-01', 'Almacén B')
# (412, 'Producto412', 'Electrónica', 173.12, 65, 'Proveedor3', '2023-12-15', 'Almacén C')
# (413, 'Artículo413', 'Deportes', 99.18, 46, 'Proveedor1', '2023-09-27', 'Almacén B')
# (414, 'Producto414', 'Moda', 28.62, 30, 'Proveedor2', '2023-04-15', 'Almacén B')
# (415, 'Artículo415', 'Moda', 85.8, 25, 'Proveedor2', '2023-05-09', 'Almacén A')
# (416, 'Objeto416', 'Moda', 444.13, 93, 'Proveedor2', '2023-10-28', 'Almacén B')
# (417, 'Producto417', 'Moda', 301.89, 15, 'Proveedor3', '2023-02-05', 'Almacén A')
# (418, 'Producto418', 'Hogar', 120.7, 96, 'Proveedor1', '2023-01-02', 'Almacén B')
# (419, 'Objeto419', 'Jardín', 270.54, 86, 'Proveedor2', '2023-05-16', 'Almacén A')
# (420, 'Objeto420', 'Moda', 320.63, 18, 'Proveedor3', '2023-06-27', 'Almacén B')
# (421, 'Producto421', 'Hogar', 214.88, 76, 'Proveedor3', '2023-07-11', 'Almacén B')
# (422, 'Artículo422', 'Hogar', 103.75, 53, 'Proveedor1', '2023-07-03', 'Almacén C')
# (423, 'Artículo423', 'Electrónica', 442.43, 53, 'Proveedor2', '2023-05-21', 'Almacén A')
# (424, 'Artículo424', 'Deportes', 255.38, 97, 'Proveedor2', '2023-09-24', 'Almacén C')
# (425, 'Artículo425', 'Deportes', 487.16, 70, 'Proveedor3', '2023-08-24', 'Almacén C')
# (426, 'Producto426', 'Hogar', 87.04, 84, 'Proveedor2', '2023-06-19', 'Almacén C')
# (427, 'Artículo427', 'Deportes', 357.67, 92, 'Proveedor3', '2023-03-16', 'Almacén A')
# (428, 'Artículo428', 'Hogar', 497.28, 97, 'Proveedor3', '2023-11-28', 'Almacén C')
# (429, 'Objeto429', 'Hogar', 177.49, 6, 'Proveedor1', '2023-06-07', 'Almacén A')
# (430, 'Producto430', 'Jardín', 405.1, 79, 'Proveedor2', '2023-09-01', 'Almacén A')
# (431, 'Objeto431', 'Moda', 131.14, 36, 'Proveedor1', '2023-08-25', 'Almacén A')
# (432, 'Producto432', 'Hogar', 484.07, 74, 'Proveedor1', '2023-07-18', 'Almacén B')
# (433, 'Objeto433', 'Hogar', 53.21, 67, 'Proveedor3', '2023-02-25', 'Almacén B')
# (434, 'Producto434', 'Hogar', 317.18, 43, 'Proveedor3', '2023-11-25', 'Almacén C')
# (435, 'Artículo435', 'Hogar', 477.09, 35, 'Proveedor3', '2023-05-13', 'Almacén B')
# (436, 'Artículo436', 'Jardín', 101.16, 56, 'Proveedor3', '2023-05-20', 'Almacén C')
# (437, 'Objeto437', 'Hogar', 281.71, 84, 'Proveedor2', '2023-09-24', 'Almacén B')
# (438, 'Producto438', 'Hogar', 225.71, 10, 'Proveedor2', '2023-06-09', 'Almacén B')
# (439, 'Artículo439', 'Jardín', 182.19, 24, 'Proveedor2', '2023-01-12', 'Almacén A')
# (440, 'Objeto440', 'Hogar', 299.65, 51, 'Proveedor3', '2023-11-15', 'Almacén B')
# (441, 'Objeto441', 'Electrónica', 273.88, 87, 'Proveedor2', '2023-09-09', 'Almacén A')
# (442, 'Producto442', 'Electrónica', 241.36, 90, 'Proveedor1', '2023-01-07', 'Almacén A')
# (443, 'Artículo443', 'Moda', 175.9, 24, 'Proveedor2', '2023-07-14', 'Almacén A')
# (444, 'Producto444', 'Jardín', 96.44, 66, 'Proveedor2', '2023-09-01', 'Almacén B')
# (445, 'Objeto445', 'Electrónica', 145.96, 24, 'Proveedor2', '2023-10-15', 'Almacén A')
# (446, 'Objeto446', 'Moda', 37.18, 14, 'Proveedor3', '2023-10-10', 'Almacén A')
# (447, 'Producto447', 'Electrónica', 119.47, 72, 'Proveedor2', '2023-01-19', 'Almacén B')
# (448, 'Artículo448', 'Electrónica', 277.98, 11, 'Proveedor2', '2023-12-06', 'Almacén B')
# (449, 'Producto449', 'Hogar', 442.82, 5, 'Proveedor1', '2023-06-21', 'Almacén B')
# (450, 'Producto450', 'Moda', 318.53, 41, 'Proveedor3', '2023-02-20', 'Almacén B')
# (451, 'Artículo451', 'Jardín', 135.66, 85, 'Proveedor3', '2023-06-28', 'Almacén B')
# (452, 'Artículo452', 'Hogar', 440.61, 24, 'Proveedor1', '2023-05-22', 'Almacén C')
# (453, 'Objeto453', 'Deportes', 80.71, 4, 'Proveedor1', '2023-12-26', 'Almacén A')
# (454, 'Producto454', 'Moda', 53.59, 6, 'Proveedor1', '2023-12-13', 'Almacén B')
# (455, 'Objeto455', 'Deportes', 267.54, 100, 'Proveedor3', '2023-07-13', 'Almacén A')
# (456, 'Producto456', 'Jardín', 493.97, 63, 'Proveedor1', '2023-10-02', 'Almacén B')
# (457, 'Objeto457', 'Electrónica', 326.37, 44, 'Proveedor1', '2023-07-10', 'Almacén A')
# (458, 'Producto458', 'Electrónica', 54.58, 61, 'Proveedor3', '2023-09-15', 'Almacén A')
# (459, 'Artículo459', 'Electrónica', 175.88, 29, 'Proveedor1', '2023-07-28', 'Almacén B')
# (460, 'Objeto460', 'Hogar', 319.45, 12, 'Proveedor1', '2023-01-11', 'Almacén A')
# (461, 'Artículo461', 'Jardín', 330.54, 35, 'Proveedor3', '2023-05-20', 'Almacén B')
# (462, 'Objeto462', 'Moda', 221.16, 83, 'Proveedor3', '2023-08-24', 'Almacén C')
# (463, 'Objeto463', 'Jardín', 216.86, 64, 'Proveedor3', '2023-07-27', 'Almacén B')
# (464, 'Artículo464', 'Jardín', 239.33, 45, 'Proveedor3', '2023-01-04', 'Almacén A')
# (465, 'Artículo465', 'Jardín', 219.7, 12, 'Proveedor3', '2023-02-03', 'Almacén C')
# (466, 'Producto466', 'Hogar', 300.34, 32, 'Proveedor1', '2023-02-07', 'Almacén B')
# (467, 'Producto467', 'Hogar', 395.97, 85, 'Proveedor2', '2023-11-13', 'Almacén A')
# (468, 'Artículo468', 'Jardín', 260.03, 39, 'Proveedor3', '2023-05-15', 'Almacén C')
# (469, 'Artículo469', 'Electrónica', 21.36, 14, 'Proveedor1', '2023-06-23', 'Almacén A')
# (470, 'Producto470', 'Jardín', 216.97, 92, 'Proveedor2', '2023-06-01', 'Almacén C')
# (471, 'Producto471', 'Jardín', 499.87, 43, 'Proveedor2', '2023-03-08', 'Almacén C')
# (472, 'Artículo472', 'Electrónica', 186.6, 10, 'Proveedor2', '2023-09-09', 'Almacén C')
# (473, 'Objeto473', 'Moda', 130.39, 73, 'Proveedor3', '2023-11-09', 'Almacén A')
# (474, 'Artículo474', 'Jardín', 78.76, 61, 'Proveedor3', '2023-11-20', 'Almacén A')
# (475, 'Artículo475', 'Moda', 423.5, 50, 'Proveedor1', '2023-02-03', 'Almacén C')
# (476, 'Producto476', 'Moda', 368.51, 58, 'Proveedor2', '2023-08-04', 'Almacén C')
# (477, 'Artículo477', 'Electrónica', 461.4, 37, 'Proveedor3', '2023-10-16', 'Almacén A')
# (478, 'Objeto478', 'Deportes', 172.05, 98, 'Proveedor3', '2023-09-25', 'Almacén A')
# (479, 'Artículo479', 'Electrónica', 147.17, 15, 'Proveedor2', '2023-06-08', 'Almacén A')
# (480, 'Artículo480', 'Electrónica', 226.36, 10, 'Proveedor3', '2023-12-22', 'Almacén B')
# (481, 'Objeto481', 'Moda', 462.25, 19, 'Proveedor1', '2023-08-03', 'Almacén C')
# (482, 'Objeto482', 'Hogar', 234.21, 39, 'Proveedor3', '2023-09-21', 'Almacén A')
# (483, 'Objeto483', 'Jardín', 361.03, 24, 'Proveedor1', '2023-03-15', 'Almacén A')
# (484, 'Artículo484', 'Electrónica', 132.02, 5, 'Proveedor1', '2023-09-28', 'Almacén A')
# (485, 'Artículo485', 'Jardín', 154.44, 27, 'Proveedor2', '2023-11-22', 'Almacén B')
# (486, 'Objeto486', 'Hogar', 475.06, 31, 'Proveedor2', '2023-06-25', 'Almacén C')
# (487, 'Producto487', 'Jardín', 316.55, 68, 'Proveedor2', '2023-05-03', 'Almacén A')
# (488, 'Objeto488', 'Moda', 152.72, 85, 'Proveedor1', '2023-08-01', 'Almacén B')
# (489, 'Artículo489', 'Jardín', 387.42, 33, 'Proveedor2', '2023-01-19', 'Almacén C')
# (490, 'Objeto490', 'Electrónica', 373.61, 74, 'Proveedor3', '2023-06-24', 'Almacén C')
# (491, 'Artículo491', 'Moda', 436.3, 79, 'Proveedor2', '2023-08-04', 'Almacén C')
# (492, 'Producto492', 'Hogar', 101.4, 38, 'Proveedor1', '2023-12-01', 'Almacén A')
# (493, 'Objeto493', 'Electrónica', 15.89, 70, 'Proveedor2', '2023-10-16', 'Almacén B')
# (494, 'Objeto494', 'Hogar', 318.8, 51, 'Proveedor2', '2023-08-06', 'Almacén C')
# (495, 'Artículo495', 'Jardín', 128.38, 53, 'Proveedor2', '2023-04-15', 'Almacén A')
# (496, 'Producto496', 'Moda', 360.08, 22, 'Proveedor3', '2023-06-05', 'Almacén A')
# (497, 'Artículo497', 'Deportes', 373.21, 92, 'Proveedor3', '2023-01-04', 'Almacén A')
# (498, 'Producto498', 'Deportes', 491.17, 22, 'Proveedor3', '2023-09-17', 'Almacén B')
# (499, 'Producto499', 'Deportes', 393.31, 10, 'Proveedor1', '2023-09-05', 'Almacén B')
# (500, 'Artículo500', 'Moda', 453.56, 21, 'Proveedor3', '2023-03-17', 'Almacén B')
# (501, 'Producto501', 'Deportes', 133.52, 4, 'Proveedor2', '2023-08-28', 'Almacén A')
# (502, 'Producto502', 'Deportes', 53.54, 1, 'Proveedor2', '2023-04-07', 'Almacén B')
# (503, 'Artículo503', 'Hogar', 116.69, 36, 'Proveedor2', '2023-07-18', 'Almacén B')
# (504, 'Artículo504', 'Moda', 486.74, 11, 'Proveedor1', '2023-10-14', 'Almacén B')
# (505, 'Producto505', 'Electrónica', 488.52, 24, 'Proveedor3', '2023-07-12', 'Almacén B')
# (506, 'Producto506', 'Moda', 499.2, 84, 'Proveedor1', '2023-03-17', 'Almacén A')
# (507, 'Objeto507', 'Electrónica', 458.51, 12, 'Proveedor2', '2023-02-03', 'Almacén B')
# (508, 'Artículo508', 'Moda', 424.57, 68, 'Proveedor1', '2023-08-20', 'Almacén B')
# (509, 'Objeto509', 'Jardín', 341.92, 67, 'Proveedor2', '2023-11-25', 'Almacén B')
# (510, 'Artículo510', 'Electrónica', 239.88, 56, 'Proveedor1', '2023-07-07', 'Almacén B')
# (511, 'Objeto511', 'Deportes', 385.83, 83, 'Proveedor3', '2023-06-16', 'Almacén A')
# (512, 'Objeto512', 'Deportes', 390.41, 36, 'Proveedor3', '2023-10-20', 'Almacén A')
# (513, 'Producto513', 'Jardín', 309.11, 90, 'Proveedor3', '2023-11-21', 'Almacén C')
# (514, 'Artículo514', 'Deportes', 200.67, 92, 'Proveedor3', '2023-10-13', 'Almacén A')
# (515, 'Producto515', 'Electrónica', 397.75, 69, 'Proveedor2', '2023-04-10', 'Almacén C')
# (516, 'Producto516', 'Moda', 397.22, 63, 'Proveedor2', '2023-05-18', 'Almacén C')
# (517, 'Artículo517', 'Deportes', 262.63, 56, 'Proveedor2', '2023-05-15', 'Almacén A')
# (518, 'Producto518', 'Deportes', 494.22, 5, 'Proveedor2', '2023-06-12', 'Almacén B')
# (519, 'Objeto519', 'Deportes', 164.56, 79, 'Proveedor2', '2023-09-21', 'Almacén C')
# (520, 'Artículo520', 'Moda', 155.42, 12, 'Proveedor1', '2023-01-13', 'Almacén B')
# (521, 'Artículo521', 'Hogar', 37.13, 36, 'Proveedor2', '2023-10-20', 'Almacén C')
# (522, 'Objeto522', 'Deportes', 383.02, 48, 'Proveedor1', '2023-02-19', 'Almacén B')
# (523, 'Objeto523', 'Jardín', 154.27, 100, 'Proveedor3', '2023-02-21', 'Almacén A')
# (524, 'Producto524', 'Jardín', 458.06, 63, 'Proveedor3', '2023-12-26', 'Almacén B')
# (525, 'Objeto525', 'Moda', 326.75, 99, 'Proveedor1', '2023-09-11', 'Almacén B')
# (526, 'Objeto526', 'Deportes', 302.49, 80, 'Proveedor2', '2023-08-20', 'Almacén B')
# (527, 'Producto527', 'Electrónica', 346.72, 77, 'Proveedor1', '2023-07-01', 'Almacén C')
# (528, 'Objeto528', 'Electrónica', 368.44, 1, 'Proveedor1', '2023-05-02', 'Almacén C')
# (529, 'Objeto529', 'Electrónica', 337.41, 87, 'Proveedor3', '2023-10-18', 'Almacén C')
# (530, 'Artículo530', 'Hogar', 93.82, 35, 'Proveedor2', '2023-08-20', 'Almacén B')
# (531, 'Artículo531', 'Moda', 356.06, 73, 'Proveedor3', '2023-12-08', 'Almacén C')
# (532, 'Producto532', 'Jardín', 350.27, 74, 'Proveedor2', '2023-04-22', 'Almacén B')
# (533, 'Artículo533', 'Deportes', 173.86, 26, 'Proveedor2', '2023-03-20', 'Almacén C')
# (534, 'Producto534', 'Electrónica', 379.85, 28, 'Proveedor1', '2023-05-22', 'Almacén A')
# (535, 'Objeto535', 'Hogar', 327.95, 74, 'Proveedor3', '2023-03-26', 'Almacén A')
# (536, 'Producto536', 'Jardín', 481.22, 50, 'Proveedor3', '2023-08-26', 'Almacén B')
# (537, 'Objeto537', 'Deportes', 221.88, 8, 'Proveedor3', '2023-12-02', 'Almacén C')
# (538, 'Objeto538', 'Jardín', 244.63, 30, 'Proveedor3', '2023-03-03', 'Almacén C')
# (539, 'Objeto539', 'Hogar', 283.39, 55, 'Proveedor3', '2023-09-16', 'Almacén B')
# (540, 'Artículo540', 'Deportes', 419.78, 65, 'Proveedor3', '2023-03-18', 'Almacén B')
# (541, 'Objeto541', 'Hogar', 14.66, 55, 'Proveedor2', '2023-03-08', 'Almacén A')
# (542, 'Producto542', 'Electrónica', 89.75, 78, 'Proveedor3', '2023-06-10', 'Almacén B')
# (543, 'Artículo543', 'Jardín', 15.57, 88, 'Proveedor3', '2023-02-02', 'Almacén B')
# (544, 'Artículo544', 'Deportes', 18.68, 1, 'Proveedor1', '2023-08-06', 'Almacén C')
# (545, 'Producto545', 'Electrónica', 307.49, 2, 'Proveedor3', '2023-01-02', 'Almacén A')
# (546, 'Artículo546', 'Hogar', 487.88, 38, 'Proveedor3', '2023-09-26', 'Almacén B')
# (547, 'Objeto547', 'Jardín', 124.16, 59, 'Proveedor3', '2023-12-24', 'Almacén B')
# (548, 'Artículo548', 'Electrónica', 272.94, 93, 'Proveedor3', '2023-10-21', 'Almacén B')
# (549, 'Artículo549', 'Jardín', 370.13, 31, 'Proveedor1', '2023-06-08', 'Almacén C')
# (550, 'Objeto550', 'Moda', 163.98, 62, 'Proveedor3', '2023-06-21', 'Almacén A')
# (551, 'Producto551', 'Deportes', 15.62, 28, 'Proveedor3', '2023-10-20', 'Almacén A')
# (552, 'Objeto552', 'Jardín', 241.62, 60, 'Proveedor3', '2023-09-10', 'Almacén A')
# (553, 'Artículo553', 'Hogar', 291.18, 63, 'Proveedor3', '2023-07-12', 'Almacén B')
# (554, 'Artículo554', 'Jardín', 75.36, 36, 'Proveedor2', '2023-08-17', 'Almacén B')
# (555, 'Objeto555', 'Jardín', 419.17, 94, 'Proveedor3', '2023-06-12', 'Almacén A')
# (556, 'Objeto556', 'Electrónica', 450.39, 97, 'Proveedor1', '2023-06-27', 'Almacén A')
# (557, 'Objeto557', 'Electrónica', 379, 38, 'Proveedor2', '2023-03-28', 'Almacén A')
# (558, 'Objeto558', 'Electrónica', 203.39, 3, 'Proveedor2', '2023-09-03', 'Almacén A')
# (559, 'Artículo559', 'Jardín', 139.39, 89, 'Proveedor3', '2023-07-04', 'Almacén C')
# (560, 'Objeto560', 'Deportes', 474.62, 73, 'Proveedor3', '2023-03-23', 'Almacén A')
# (561, 'Producto561', 'Electrónica', 499.22, 84, 'Proveedor3', '2023-01-10', 'Almacén A')
# (562, 'Artículo562', 'Deportes', 97.44, 32, 'Proveedor3', '2023-02-13', 'Almacén B')
# (563, 'Artículo563', 'Hogar', 176.53, 35, 'Proveedor1', '2023-06-16', 'Almacén A')
# (564, 'Objeto564', 'Hogar', 78.63, 92, 'Proveedor3', '2023-11-19', 'Almacén A')
# (565, 'Artículo565', 'Moda', 177.2, 8, 'Proveedor1', '2023-09-22', 'Almacén B')
# (566, 'Producto566', 'Hogar', 341.96, 82, 'Proveedor2', '2023-06-15', 'Almacén C')
# (567, 'Artículo567', 'Deportes', 387.01, 29, 'Proveedor1', '2023-04-25', 'Almacén C')
# (568, 'Objeto568', 'Deportes', 97.39, 29, 'Proveedor3', '2023-03-20', 'Almacén A')
# (569, 'Producto569', 'Electrónica', 375.69, 84, 'Proveedor3', '2023-02-15', 'Almacén B')
# (570, 'Artículo570', 'Moda', 170.89, 11, 'Proveedor2', '2023-03-07', 'Almacén C')
# (571, 'Producto571', 'Hogar', 337.46, 69, 'Proveedor3', '2023-05-12', 'Almacén B')
# (572, 'Artículo572', 'Deportes', 285.42, 85, 'Proveedor1', '2023-04-04', 'Almacén C')
# (573, 'Artículo573', 'Jardín', 496.53, 37, 'Proveedor2', '2023-08-25', 'Almacén A')
# (574, 'Artículo574', 'Moda', 226.71, 70, 'Proveedor1', '2023-01-03', 'Almacén A')
# ...
# (14820, 'Producto4817', 'Deportes', 259.69, 15, 'Proveedor1', '2025-03-10', 'Almacén A')
# (14821, 'Producto4818', 'Deportes', 360.17, 72, 'Proveedor2', '2025-04-02', 'Almacén A')
# (14822, 'Producto4819', 'Moda', 71.83, 87, 'Proveedor2', '2024-10-25', 'Almacén B')
# (14823, 'Producto4820', 'Electrónica', 414.9, 90, 'Proveedor1', '2025-08-29', 'Almacén A')
# (14824, 'Producto4821', 'Jardín', 191.91, 6, 'Proveedor3', '2025-08-01', 'Almacén C')
# (14825, 'Producto4822', 'Moda', 150.67, 72, 'Proveedor2', '2025-05-05', 'Almacén B')
# (14826, 'Producto4823', 'Hogar', 364.75, 91, 'Proveedor2', '2025-07-01', 'Almacén A')
# (14827, 'Producto4824', 'Hogar', 225.02, 2, 'Proveedor1', '2025-06-10', 'Almacén C')
# (14828, 'Producto4825', 'Hogar', 47.72, 72, 'Proveedor1', '2024-12-02', 'Almacén B')
# (14829, 'Producto4826', 'Electrónica', 387.16, 38, 'Proveedor3', '2024-11-10', 'Almacén A')
# (14830, 'Producto4827', 'Hogar', 495.59, 37, 'Proveedor3', '2025-04-09', 'Almacén C')
# (14831, 'Producto4828', 'Hogar', 157.6, 11, 'Proveedor1', '2024-11-30', 'Almacén B')
# (14832, 'Producto4829', 'Deportes', 427.21, 3, 'Proveedor1', '2025-01-19', 'Almacén B')
# (14833, 'Producto4830', 'Deportes', 60.95, 26, 'Proveedor1', '2025-02-23', 'Almacén B')
# (14834, 'Producto4831', 'Deportes', 110.1, 45, 'Proveedor1', '2025-05-04', 'Almacén A')
# (14835, 'Producto4832', 'Electrónica', 13.56, 95, 'Proveedor2', '2025-04-12', 'Almacén A')
# (14836, 'Producto4833', 'Hogar', 103.58, 72, 'Proveedor1', '2025-10-06', 'Almacén B')
# (14837, 'Producto4834', 'Moda', 333.57, 35, 'Proveedor1', '2025-06-22', 'Almacén A')
# (14838, 'Producto4835', 'Hogar', 152.91, 61, 'Proveedor1', '2025-04-15', 'Almacén C')
# (14839, 'Producto4836', 'Deportes', 30.34, 10, 'Proveedor2', '2025-04-27', 'Almacén A')
# (14840, 'Producto4837', 'Hogar', 16.12, 14, 'Proveedor3', '2025-03-07', 'Almacén A')
# (14841, 'Producto4838', 'Deportes', 159.02, 38, 'Proveedor2', '2025-05-28', 'Almacén B')
# (14842, 'Producto4839', 'Hogar', 127.77, 54, 'Proveedor2', '2025-08-20', 'Almacén B')
# (14843, 'Producto4840', 'Electrónica', 200.22, 62, 'Proveedor2', '2025-04-15', 'Almacén B')
# (14844, 'Producto4841', 'Jardín', 186.32, 86, 'Proveedor2', '2025-05-25', 'Almacén C')
# (14845, 'Producto4842', 'Jardín', 71.83, 20, 'Proveedor3', '2025-03-02', 'Almacén C')
# (14846, 'Producto4843', 'Hogar', 175.33, 81, 'Proveedor2', '2024-10-20', 'Almacén B')
# (14847, 'Producto4844', 'Moda', 387.39, 12, 'Proveedor1', '2025-06-08', 'Almacén B')
# (14848, 'Producto4845', 'Hogar', 42.52, 90, 'Proveedor2', '2025-07-02', 'Almacén A')
# (14849, 'Producto4846', 'Hogar', 118.15, 8, 'Proveedor2', '2024-11-16', 'Almacén A')
# (14850, 'Producto4847', 'Jardín', 117.09, 99, 'Proveedor1', '2025-05-19', 'Almacén B')
# (14851, 'Producto4848', 'Hogar', 48.35, 51, 'Proveedor2', '2024-12-06', 'Almacén A')
# (14852, 'Producto4849', 'Hogar', 424.99, 27, 'Proveedor2', '2025-09-15', 'Almacén C')
# (14853, 'Producto4850', 'Deportes', 423, 94, 'Proveedor3', '2025-07-28', 'Almacén B')
# (14854, 'Producto4851', 'Hogar', 283.78, 74, 'Proveedor2', '2025-02-20', 'Almacén B')
# (14855, 'Producto4852', 'Deportes', 260.17, 10, 'Proveedor2', '2025-05-17', 'Almacén A')
# (14856, 'Producto4853', 'Electrónica', 10.32, 55, 'Proveedor2', '2025-07-22', 'Almacén C')
# (14857, 'Producto4854', 'Moda', 136.17, 51, 'Proveedor3', '2025-06-07', 'Almacén B')
# (14858, 'Producto4855', 'Hogar', 444.46, 11, 'Proveedor3', '2025-08-13', 'Almacén C')
# (14859, 'Producto4856', 'Deportes', 338.52, 78, 'Proveedor2', '2024-12-27', 'Almacén B')
# (14860, 'Producto4857', 'Deportes', 171.03, 53, 'Proveedor1', '2025-01-05', 'Almacén C')
# (14861, 'Producto4858', 'Hogar', 52.13, 53, 'Proveedor1', '2025-08-22', 'Almacén A')
# (14862, 'Producto4859', 'Jardín', 472.84, 50, 'Proveedor1', '2024-12-21', 'Almacén B')
# (14863, 'Producto4860', 'Jardín', 273.01, 88, 'Proveedor3', '2024-11-17', 'Almacén C')
# (14864, 'Producto4861', 'Hogar', 404.17, 93, 'Proveedor2', '2025-01-19', 'Almacén A')
# (14865, 'Producto4862', 'Hogar', 474.36, 78, 'Proveedor2', '2025-07-03', 'Almacén C')
# (14866, 'Producto4863', 'Jardín', 255.27, 87, 'Proveedor2', '2025-03-23', 'Almacén A')
# (14867, 'Producto4864', 'Hogar', 491.24, 99, 'Proveedor2', '2025-06-25', 'Almacén C')
# (14868, 'Producto4865', 'Hogar', 441.98, 88, 'Proveedor2', '2025-08-07', 'Almacén A')
# (14869, 'Producto4866', 'Jardín', 338.96, 79, 'Proveedor3', '2024-11-21', 'Almacén C')
# (14870, 'Producto4867', 'Deportes', 111.13, 24, 'Proveedor1', '2025-02-22', 'Almacén B')
# (14871, 'Producto4868', 'Electrónica', 101.95, 38, 'Proveedor2', '2024-11-17', 'Almacén A')
# (14872, 'Producto4869', 'Hogar', 132.81, 31, 'Proveedor3', '2025-04-26', 'Almacén C')
# (14873, 'Producto4870', 'Jardín', 342.83, 47, 'Proveedor2', '2025-03-28', 'Almacén A')
# (14874, 'Producto4871', 'Hogar', 69.98, 96, 'Proveedor2', '2025-09-18', 'Almacén A')
# (14875, 'Producto4872', 'Hogar', 88.23, 36, 'Proveedor1', '2025-04-05', 'Almacén C')
# (14876, 'Producto4873', 'Deportes', 38.48, 44, 'Proveedor2', '2025-06-01', 'Almacén B')
# (14877, 'Producto4874', 'Electrónica', 471.52, 8, 'Proveedor2', '2025-02-10', 'Almacén A')
# (14878, 'Producto4875', 'Hogar', 390.01, 19, 'Proveedor2', '2025-06-04', 'Almacén C')
# (14879, 'Producto4876', 'Electrónica', 161.14, 32, 'Proveedor2', '2025-07-06', 'Almacén C')
# (14880, 'Producto4877', 'Jardín', 297.02, 7, 'Proveedor1', '2025-08-28', 'Almacén C')
# (14881, 'Producto4878', 'Jardín', 83.07, 80, 'Proveedor2', '2025-04-16', 'Almacén A')
# (14882, 'Producto4879', 'Moda', 231.8, 58, 'Proveedor2', '2025-09-30', 'Almacén B')
# (14883, 'Producto4880', 'Deportes', 137.46, 55, 'Proveedor3', '2025-04-05', 'Almacén B')
# (14884, 'Producto4881', 'Jardín', 112.71, 17, 'Proveedor2', '2025-08-28', 'Almacén C')
# (14885, 'Producto4882', 'Hogar', 456, 62, 'Proveedor2', '2025-02-02', 'Almacén B')
# (14886, 'Producto4883', 'Hogar', 34.91, 44, 'Proveedor3', '2025-01-04', 'Almacén C')
# (14887, 'Producto4884', 'Jardín', 115.48, 66, 'Proveedor3', '2025-04-16', 'Almacén B')
# (14888, 'Producto4885', 'Moda', 432.47, 39, 'Proveedor3', '2025-03-01', 'Almacén C')
# (14889, 'Producto4886', 'Deportes', 463.53, 74, 'Proveedor1', '2024-11-02', 'Almacén C')
# (14890, 'Producto4887', 'Moda', 377.24, 68, 'Proveedor3', '2025-01-09', 'Almacén A')
# (14891, 'Producto4888', 'Electrónica', 336.14, 88, 'Proveedor2', '2024-11-04', 'Almacén C')
# (14892, 'Producto4889', 'Deportes', 270.06, 70, 'Proveedor1', '2025-01-06', 'Almacén B')
# (14893, 'Producto4890', 'Deportes', 218.81, 65, 'Proveedor2', '2025-03-20', 'Almacén C')
# (14894, 'Producto4891', 'Hogar', 224.65, 71, 'Proveedor3', '2024-11-23', 'Almacén A')
# (14895, 'Producto4892', 'Deportes', 371.02, 67, 'Proveedor1', '2024-11-11', 'Almacén A')
# (14896, 'Producto4893', 'Deportes', 200.32, 72, 'Proveedor2', '2024-10-24', 'Almacén C')
# (14897, 'Producto4894', 'Hogar', 88.41, 24, 'Proveedor2', '2025-06-17', 'Almacén B')
# (14898, 'Producto4895', 'Deportes', 442.67, 97, 'Proveedor1', '2025-05-20', 'Almacén C')
# (14899, 'Producto4896', 'Moda', 189.64, 64, 'Proveedor3', '2025-05-10', 'Almacén C')
# (14900, 'Producto4897', 'Deportes', 218.32, 40, 'Proveedor2', '2025-05-17', 'Almacén B')
# (14901, 'Producto4898', 'Jardín', 370.47, 71, 'Proveedor1', '2025-08-06', 'Almacén A')
# (14902, 'Producto4899', 'Deportes', 35.73, 9, 'Proveedor3', '2025-05-20', 'Almacén C')
# (14903, 'Producto4900', 'Deportes', 140.45, 83, 'Proveedor1', '2025-03-07', 'Almacén C')
# (14904, 'Producto4901', 'Electrónica', 160.46, 7, 'Proveedor1', '2025-04-25', 'Almacén B')
# (14905, 'Producto4902', 'Electrónica', 333.46, 33, 'Proveedor2', '2025-05-01', 'Almacén A')
# (14906, 'Producto4903', 'Moda', 305.57, 52, 'Proveedor1', '2025-06-29', 'Almacén C')
# (14907, 'Producto4904', 'Electrónica', 430.63, 15, 'Proveedor1', '2025-08-21', 'Almacén C')
# (14908, 'Producto4905', 'Moda', 155.38, 32, 'Proveedor2', '2025-09-15', 'Almacén A')
# (14909, 'Producto4906', 'Electrónica', 40.32, 90, 'Proveedor3', '2025-02-28', 'Almacén A')
# (14910, 'Producto4907', 'Electrónica', 322.32, 13, 'Proveedor1', '2025-06-17', 'Almacén B')
# (14911, 'Producto4908', 'Hogar', 443.06, 25, 'Proveedor3', '2025-03-26', 'Almacén A')
# (14912, 'Producto4909', 'Moda', 49.91, 53, 'Proveedor3', '2024-11-07', 'Almacén C')
# (14913, 'Producto4910', 'Deportes', 262.52, 62, 'Proveedor2', '2025-01-10', 'Almacén A')
# (14914, 'Producto4911', 'Electrónica', 227.84, 51, 'Proveedor1', '2025-09-10', 'Almacén B')
# (14915, 'Producto4912', 'Moda', 189.64, 79, 'Proveedor2', '2025-05-11', 'Almacén C')
# (14916, 'Producto4913', 'Deportes', 326.14, 10, 'Proveedor1', '2025-01-30', 'Almacén B')
# (14917, 'Producto4914', 'Electrónica', 183.92, 23, 'Proveedor1', '2025-04-21', 'Almacén C')
# (14918, 'Producto4915', 'Jardín', 373.96, 77, 'Proveedor1', '2024-12-05', 'Almacén C')
# (14919, 'Producto4916', 'Deportes', 42.2, 38, 'Proveedor2', '2025-03-23', 'Almacén B')
# (14920, 'Producto4917', 'Electrónica', 213.78, 98, 'Proveedor3', '2025-04-30', 'Almacén A')
# (14921, 'Producto4918', 'Electrónica', 233.47, 69, 'Proveedor2', '2025-08-14', 'Almacén B')
# (14922, 'Producto4919', 'Deportes', 433.76, 46, 'Proveedor2', '2025-10-10', 'Almacén B')
# (14923, 'Producto4920', 'Moda', 108.01, 47, 'Proveedor2', '2024-11-26', 'Almacén C')
# (14924, 'Producto4921', 'Hogar', 290.37, 20, 'Proveedor1', '2025-08-02', 'Almacén A')
# (14925, 'Producto4922', 'Electrónica', 238.88, 41, 'Proveedor1', '2025-08-31', 'Almacén C')
# (14926, 'Producto4923', 'Moda', 262.48, 69, 'Proveedor2', '2025-04-26', 'Almacén A')
# (14927, 'Producto4924', 'Jardín', 132.96, 11, 'Proveedor2', '2025-07-24', 'Almacén B')
# (14928, 'Producto4925', 'Deportes', 267.99, 12, 'Proveedor1', '2025-02-24', 'Almacén B')
# (14929, 'Producto4926', 'Moda', 15.42, 56, 'Proveedor3', '2025-02-28', 'Almacén C')
# (14930, 'Producto4927', 'Moda', 323.17, 12, 'Proveedor2', '2025-06-14', 'Almacén B')
# (14931, 'Producto4928', 'Moda', 308.15, 2, 'Proveedor3', '2025-04-25', 'Almacén A')
# (14932, 'Producto4929', 'Hogar', 196.79, 69, 'Proveedor1', '2025-02-28', 'Almacén C')
# (14933, 'Producto4930', 'Hogar', 489.76, 74, 'Proveedor1', '2024-10-22', 'Almacén B')
# (14934, 'Producto4931', 'Jardín', 294.41, 92, 'Proveedor3', '2025-07-04', 'Almacén B')
# (14935, 'Producto4932', 'Electrónica', 199.08, 96, 'Proveedor1', '2025-01-16', 'Almacén A')
# (14936, 'Producto4933', 'Hogar', 337.55, 53, 'Proveedor3', '2025-04-06', 'Almacén B')
# (14937, 'Producto4934', 'Hogar', 430.38, 47, 'Proveedor1', '2025-04-20', 'Almacén C')
# (14938, 'Producto4935', 'Hogar', 78.21, 85, 'Proveedor3', '2025-10-02', 'Almacén A')
# (14939, 'Producto4936', 'Hogar', 216.79, 20, 'Proveedor3', '2025-04-29', 'Almacén C')
# (14940, 'Producto4937', 'Jardín', 409.99, 38, 'Proveedor2', '2025-09-28', 'Almacén C')
# (14941, 'Producto4938', 'Moda', 215.51, 28, 'Proveedor2', '2024-11-11', 'Almacén B')
# (14942, 'Producto4939', 'Deportes', 281.86, 55, 'Proveedor1', '2025-03-10', 'Almacén A')
# (14943, 'Producto4940', 'Deportes', 97.91, 23, 'Proveedor1', '2024-10-22', 'Almacén A')
# (14944, 'Producto4941', 'Moda', 79.81, 32, 'Proveedor2', '2025-04-23', 'Almacén A')
# (14945, 'Producto4942', 'Electrónica', 324.78, 28, 'Proveedor1', '2025-06-17', 'Almacén A')
# (14946, 'Producto4943', 'Jardín', 17, 3, 'Proveedor1', '2025-08-31', 'Almacén A')
# (14947, 'Producto4944', 'Jardín', 470.33, 54, 'Proveedor2', '2025-06-29', 'Almacén A')
# (14948, 'Producto4945', 'Hogar', 122.51, 35, 'Proveedor1', '2025-06-29', 'Almacén B')
# (14949, 'Producto4946', 'Moda', 45.5, 81, 'Proveedor3', '2025-01-10', 'Almacén C')
# (14950, 'Producto4947', 'Hogar', 50.47, 19, 'Proveedor1', '2025-06-24', 'Almacén A')
# (14951, 'Producto4948', 'Deportes', 237.36, 42, 'Proveedor1', '2025-05-05', 'Almacén A')
# (14952, 'Producto4949', 'Deportes', 350.31, 39, 'Proveedor3', '2024-11-19', 'Almacén C')
# (14953, 'Producto4950', 'Moda', 467.83, 68, 'Proveedor2', '2025-02-03', 'Almacén C')
# (14954, 'Producto4951', 'Deportes', 234.05, 34, 'Proveedor2', '2025-06-28', 'Almacén A')
# (14955, 'Producto4952', 'Jardín', 38.23, 72, 'Proveedor1', '2025-09-04', 'Almacén B')
# (14956, 'Producto4953', 'Hogar', 445.38, 19, 'Proveedor2', '2025-01-02', 'Almacén C')
# (14957, 'Producto4954', 'Jardín', 107.39, 71, 'Proveedor3', '2024-10-31', 'Almacén C')
# (14958, 'Producto4955', 'Moda', 356.87, 7, 'Proveedor2', '2025-06-01', 'Almacén B')
# (14959, 'Producto4956', 'Moda', 266.98, 47, 'Proveedor3', '2025-03-13', 'Almacén B')
# (14960, 'Producto4957', 'Deportes', 169.87, 88, 'Proveedor3', '2025-04-03', 'Almacén A')
# (14961, 'Producto4958', 'Electrónica', 52.93, 89, 'Proveedor3', '2025-09-19', 'Almacén A')
# (14962, 'Producto4959', 'Electrónica', 302.22, 65, 'Proveedor1', '2025-07-21', 'Almacén C')
# (14963, 'Producto4960', 'Moda', 118.31, 36, 'Proveedor2', '2024-12-22', 'Almacén C')
# (14964, 'Producto4961', 'Jardín', 303.52, 3, 'Proveedor1', '2025-10-08', 'Almacén C')
# (14965, 'Producto4962', 'Hogar', 313.77, 61, 'Proveedor3', '2025-05-23', 'Almacén A')
# (14966, 'Producto4963', 'Electrónica', 302.66, 50, 'Proveedor1', '2025-05-28', 'Almacén C')
# (14967, 'Producto4964', 'Electrónica', 88.97, 22, 'Proveedor3', '2025-04-24', 'Almacén C')
# (14968, 'Producto4965', 'Jardín', 241.3, 63, 'Proveedor2', '2025-05-15', 'Almacén C')
# (14969, 'Producto4966', 'Moda', 322.51, 47, 'Proveedor2', '2025-01-09', 'Almacén A')
# (14970, 'Producto4967', 'Deportes', 12.26, 74, 'Proveedor1', '2025-08-08', 'Almacén A')
# (14971, 'Producto4968', 'Jardín', 362.65, 22, 'Proveedor3', '2025-07-12', 'Almacén B')
# (14972, 'Producto4969', 'Moda', 177.7, 65, 'Proveedor1', '2025-07-02', 'Almacén A')
# (14973, 'Producto4970', 'Hogar', 185.44, 60, 'Proveedor3', '2025-01-24', 'Almacén B')
# (14974, 'Producto4971', 'Moda', 28.02, 1, 'Proveedor2', '2025-01-29', 'Almacén B')
# (14975, 'Producto4972', 'Deportes', 327.76, 42, 'Proveedor3', '2025-01-02', 'Almacén B')
# (14976, 'Producto4973', 'Moda', 377.44, 63, 'Proveedor3', '2024-12-13', 'Almacén B')
# (14977, 'Producto4974', 'Moda', 218.52, 36, 'Proveedor2', '2025-06-16', 'Almacén A')
# (14978, 'Producto4975', 'Jardín', 84.77, 32, 'Proveedor2', '2025-01-29', 'Almacén A')
# (14979, 'Producto4976', 'Deportes', 71.34, 69, 'Proveedor3', '2025-01-25', 'Almacén A')
# (14980, 'Producto4977', 'Deportes', 103.17, 73, 'Proveedor2', '2025-08-23', 'Almacén C')
# (14981, 'Producto4978', 'Electrónica', 497.09, 41, 'Proveedor3', '2025-07-16', 'Almacén B')
# (14982, 'Producto4979', 'Electrónica', 228.59, 71, 'Proveedor3', '2025-01-30', 'Almacén C')
# (14983, 'Producto4980', 'Hogar', 332.18, 80, 'Proveedor2', '2025-07-11', 'Almacén A')
# (14984, 'Producto4981', 'Hogar', 355.31, 23, 'Proveedor2', '2025-02-24', 'Almacén B')
# (14985, 'Producto4982', 'Deportes', 75.51, 86, 'Proveedor2', '2024-12-19', 'Almacén B')
# (14986, 'Producto4983', 'Moda', 178.89, 46, 'Proveedor1', '2025-06-30', 'Almacén A')
# (14987, 'Producto4984', 'Electrónica', 429.12, 20, 'Proveedor2', '2024-12-01', 'Almacén C')
# (14988, 'Producto4985', 'Hogar', 209.89, 57, 'Proveedor1', '2024-11-15', 'Almacén A')
# (14989, 'Producto4986', 'Deportes', 316.62, 23, 'Proveedor2', '2025-03-28', 'Almacén C')
# (14990, 'Producto4987', 'Moda', 326.17, 72, 'Proveedor1', '2024-11-23', 'Almacén A')
# (14991, 'Producto4988', 'Jardín', 236.59, 76, 'Proveedor2', '2024-11-17', 'Almacén C')
# (14992, 'Producto4989', 'Moda', 382.21, 16, 'Proveedor1', '2024-12-31', 'Almacén A')
# (14993, 'Producto4990', 'Electrónica', 339.44, 76, 'Proveedor2', '2025-09-10', 'Almacén A')
# (14994, 'Producto4991', 'Moda', 40.85, 47, 'Proveedor2', '2025-08-11', 'Almacén C')
# (14995, 'Producto4992', 'Electrónica', 453.11, 50, 'Proveedor2', '2025-01-19', 'Almacén C')
# (14996, 'Producto4993', 'Jardín', 134.88, 10, 'Proveedor3', '2024-11-08', 'Almacén A')
# (14997, 'Producto4994', 'Moda', 161.44, 97, 'Proveedor1', '2025-05-25', 'Almacén A')
# (14998, 'Producto4995', 'Jardín', 440.86, 36, 'Proveedor3', '2025-07-08', 'Almacén C')
# (14999, 'Producto4996', 'Electrónica', 202.42, 50, 'Proveedor3', '2025-09-15', 'Almacén A')
# (15000, 'Producto4997', 'Electrónica', 328.31, 35, 'Proveedor1', '2024-10-30', 'Almacén C')
# (15001, 'Producto4998', 'Electrónica', 286.54, 5, 'Proveedor3', '2024-12-08', 'Almacén A')
# (15002, 'Producto4999', 'Deportes', 415.48, 75, 'Proveedor2', '2025-01-02', 'Almacén C')

# %% [markdown]
# ## Realizar consulta y transferir a dataframe

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)

# Cerrar la conexión
conn.close()
# Out:
#          id        nombre    categoria  precio  cantidad   proveedor  \
# 0        10    Producto10     Deportes  460.67        81  Proveedor2
# 1        18    Artículo18        Hogar  481.32        15  Proveedor1
# 2        25      Objeto25  Electrónica  450.23        92  Proveedor2
# 3        34    Producto34  Electrónica  491.92        27  Proveedor2
# 4        38    Producto38  Electrónica  471.75         7  Proveedor1
# ...     ...           ...          ...     ...       ...         ...
# 1515  14933  Producto4930        Hogar  489.76        74  Proveedor1
# 1516  14947  Producto4944       Jardín  470.33        54  Proveedor2
# 1517  14953  Producto4950         Moda  467.83        68  Proveedor2
# 1518  14981  Producto4978  Electrónica  497.09        41  Proveedor3
# 1519  14995  Producto4992  Electrónica  453.11        50  Proveedor2
#
#      fecha_ingreso  ubicacion
# 0       2023-08-28  Almacén B
# 1       2023-03-22  Almacén A
# 2       2023-08-25  Almacén C
# 3       2023-10-01  Almacén A
# 4       2023-02-28  Almacén A
# ...            ...        ...
# 1515    2024-10-22  Almacén B
# 1516    2025-06-29  Almacén A
# 1517    2025-02-03  Almacén C
# 1518    2025-07-16  Almacén B
# 1519    2025-01-19  Almacén C
#
# [1520 rows x 8 columns]

# %%
df_productos.head()
# Out:
#    id      nombre    categoria  precio  cantidad   proveedor fecha_ingreso  \
# 0  10  Producto10     Deportes  460.67        81  Proveedor2    2023-08-28
# 1  18  Artículo18        Hogar  481.32        15  Proveedor1    2023-03-22
# 2  25    Objeto25  Electrónica  450.23        92  Proveedor2    2023-08-25
# 3  34  Producto34  Electrónica  491.92        27  Proveedor2    2023-10-01
# 4  38  Producto38  Electrónica  471.75         7  Proveedor1    2023-02-28
#
#    ubicacion
# 0  Almacén B
# 1  Almacén A
# 2  Almacén C
# 3  Almacén A
# 4  Almacén A

# %% [markdown]
# ## Nueva consulta

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450 AND cantidad > 25"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)


# Cerrar la conexión
conn.close()
# Out:
#          id        nombre    categoria  precio  cantidad   proveedor  \
# 0        10    Producto10     Deportes  460.67        81  Proveedor2
# 1        25      Objeto25  Electrónica  450.23        92  Proveedor2
# 2        34    Producto34  Electrónica  491.92        27  Proveedor2
# 3        60    Artículo60        Hogar  486.39        89  Proveedor3
# 4        61    Producto61       Jardín  485.71        96  Proveedor3
# ...     ...           ...          ...     ...       ...         ...
# 1132  14933  Producto4930        Hogar  489.76        74  Proveedor1
# 1133  14947  Producto4944       Jardín  470.33        54  Proveedor2
# 1134  14953  Producto4950         Moda  467.83        68  Proveedor2
# 1135  14981  Producto4978  Electrónica  497.09        41  Proveedor3
# 1136  14995  Producto4992  Electrónica  453.11        50  Proveedor2
#
#      fecha_ingreso  ubicacion
# 0       2023-08-28  Almacén B
# 1       2023-08-25  Almacén C
# 2       2023-10-01  Almacén A
# 3       2023-12-12  Almacén C
# 4       2023-01-25  Almacén B
# ...            ...        ...
# 1132    2024-10-22  Almacén B
# 1133    2025-06-29  Almacén A
# 1134    2025-02-03  Almacén C
# 1135    2025-07-16  Almacén B
# 1136    2025-01-19  Almacén C
#
# [1137 rows x 8 columns]

# %% [markdown]
# ## Insertar nuevo producto

# %%
# Datos del nuevo producto
nuevo_producto = (
    None,  # SQLite genera un nuevo id automáticamente si la columna es autoincrement
    'NuevoProducto123',
    'Electrónica',
    249.99,
    20,
    'ProveedorX',
    '2024-04-16',
    'Almacén D'
)

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de nuevo producto
c.execute('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', nuevo_producto)

# Guardar (commit) los cambios y cerrar conexión con la DB
conn.commit()
conn.close()

# %% [markdown]
# ## Insertar nuevo producto desde Excel

# %% [markdown]
# ### Crear tabla excel de nuevos productos

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

np.random.seed(0)
num_prods = 5000

# Productos nuevos
nombres = ['Producto' + str(i) for i in range(num_prods)]
categorias = np.random.choice(['Electrónica', 'Hogar', 'Jardín', 'Moda', 'Deportes'], num_prods)
precios = np.round(np.random.uniform(10.0, 500.0, num_prods), 2)
cantidades = np.random.randint(1, 100, num_prods)
proveedores = np.random.choice(['Proveedor1', 'Proveedor2', 'Proveedor3'], num_prods)
fechas = [datetime.today() - timedelta(days=np.random.randint(0, 365)) for _ in range(num_prods)]
ubicaciones = np.random.choice(['Almacén A', 'Almacén B', 'Almacén C'], num_prods)

# DataFrame
df = pd.DataFrame({
    'Nombre': nombres,
    'Categoría': categorias,
    'Precio': precios,
    'Cantidad': cantidades,
    'Proveedor': proveedores,
    'Fecha de Ingreso': pd.to_datetime(fechas),
    'Ubicación': ubicaciones
})

print(df.head())

# Guardar el DataFrame en un archivo Excel
df.to_excel('nuevos_productos_inventario.xlsx', index=False)
# Out:
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#             Fecha de Ingreso  Ubicación
# 0 2025-06-06 15:06:27.722141  Almacén B
# 1 2025-03-11 15:06:27.722197  Almacén C
# 2 2024-12-17 15:06:27.722213  Almacén B
# 3 2025-08-14 15:06:27.722225  Almacén A
# 4 2024-11-30 15:06:27.722235  Almacén A

# %% [markdown]
# ### Agregar datos de tabla excel al inventario

# %%
import pandas as pd

# Leer archivo Excel
ruta_archivo = '/content/nuevos_productos_inventario.xlsx'
df = pd.read_excel(ruta_archivo)

# Verificación de formatos (tipo de dato)
# Precio a float
if df['Precio'].dtype != 'float':
    df['Precio'] = df['Precio'].astype(float)

# Fecha de Ingreso a datetime
if df['Fecha de Ingreso'].dtype != 'datetime64[ns]':
    df['Fecha de Ingreso'] = pd.to_datetime(df['Fecha de Ingreso'], errors='coerce')

# Verificar y corregir fechas no válidas, usando la fecha de hoy
df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)

df.head()
# Out:
# /tmp/ipython-input-1041989223.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#          Fecha de Ingreso  Ubicación
# 0 2025-06-06 15:06:27.722  Almacén B
# 1 2025-03-11 15:06:27.722  Almacén C
# 2 2024-12-17 15:06:27.722  Almacén B
# 3 2025-08-14 15:06:27.722  Almacén A
# 4 2024-11-30 15:06:27.722  Almacén A

# %%
import sqlite3

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de datos en la DB
for index, row in df.iterrows():
    c.execute("""
        INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
        VALUES (?, ?, ?, ?, ?, ?, ?)""", (row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], row['Fecha de Ingreso'].strftime('%Y-%m-%d'), row['Ubicación']))


# # Insersión de datos en la DB
#for index, row in df.iterrows():
#    c.executemany("""
#         INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
#         VALUES(?, ?, ?, ?, ?, ?,)""",
#         [row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], row['Fecha de Ingreso'], row['Ubicación']])

# Guardar cambios y cerrar conexión con DB
conn.commit()
conn.close()

print("¡Datos importados exitosamente!")
# Out:
# ¡Datos importados exitosamente!
